# %%
from pathlib import Path
import sys

PROJECT_DIR = Path.cwd().resolve().parents[0]  # notebooks/ -> projeto P01
SRC_DIR = PROJECT_DIR / "src"
sys.path.insert(0, str(SRC_DIR))

# %%
from plot_functions import plot_series, plot_rolling_statistics
from utils_timeseries import load_timeseries, fill_missing
