# %% [markdown]
# # Notebook 04 — Executive Insights and Next Steps
#
# ## Spotify Global Music Intelligence
#
# Este notebook consolidará os principais achados, recomendações executivas, limitações e próximos passos para modelagem e produto de dados.

# %%
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
PROJECT_ROOT
