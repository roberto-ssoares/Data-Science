# %% [markdown]
# # Notebook 02 — Data Quality and Preparation
#
# ## Spotify Global Music Intelligence
#
# Este notebook será usado para avaliar qualidade, tratar inconsistências, padronizar colunas e preparar a camada Silver.

# %%
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
PROJECT_ROOT
