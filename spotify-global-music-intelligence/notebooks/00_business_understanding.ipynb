# %% [markdown]
# <div style="background-color:#F3F2EE">
#     <br /><br />
#         <p style="text-align: center;">
#             <font size="6" color='#0A1781'>
#                 <strong>
#                     Spotify Global Music Intelligence - Data Science Projects
#                 </strong>
#               </font>
#         </p>
#         <p style="text-align: center;">
#             <font size="6" color='#C58A1E'>
#                 <strong>
#                     Business Understanding
#                 </strong>
#             </font>
#         </p>
#         <p style="text-align: center;">
#             <font size="5" color='#C58A1E'>
#                 <strong>
#                     EDA Estratégica para Tendências Musicais, Popularidade de Artistas e Potencial de Hits
#                 </strong>
#             </font>
#         </p>
#     <br />
# </div>

# %% [markdown]
# <div style="background-color:#F3F2EE">
#     <p style="text-align: right;">
#       <font size="4" color='#444444'>
#             Roberto SSoares - LfLngLrnng
#       </font>
#     </p>
#     <p style="text-align: right;"><font size="2" color='#444444'>
#         <a href="https://www.linkedin.com/in/roberto-dos-santos-soares/">in/roberto-dos-santos-soares</a><br /><a href="https://roberto-ssoares.github.io/meu-portfolio/">Portifólio: roberto-ssoares</a>
#     </p>
#     <p style="text-align: right;">
#         <font size="4" color='#444444'>
#             Data Science = { "+"; "Faturamento", "-"; "Custo", ">"; "Qualidade de vida" }
#         </font>
#         <br />
#         <font size="2" color='#918e8e'>"Mestre Bruno Jardim"
#         </font>
#     </p>
#     <p style="text-align: right;">
#         <font size="2" color='#918e8e'>
#         </font>
#     </p>
# </div>

# %% [markdown]
# <div style="background-color:#f3f2ee">
#
# <font size="4" color='#CC403E'><strong>📌 Abertura executiva</strong></font>
#
# <font size="2" color='#66666'>
#
# >- Este notebook marca o início do projeto **Spotify Global Music Intelligence**,
#     - uma iniciativa analítica orientada à investigação de padrões de popularidade musical,
#     - evolução temporal de faixas,
#     - comportamento de artistas e
#     - oportunidades de aplicação de dados no mercado de streaming.
#
# >- O projeto utiliza o dataset **Spotify Global Music Dataset (2009–2025)** como base para construir uma análise exploratória de dados com abordagem profissional, conectando:
#     - fundamentos de EDA,
#     - entendimento de negócio,
#     - hipóteses analíticas,
#     - qualidade de dados,
#     - visualização e
#     - preparação para futuras etapas de modelagem preditiva.
#
# >- A proposta central é tratar este projeto não apenas como um exercício técnico,
#     - mas como uma simulação realista de consultoria em dados para uma empresa fictícia de inteligência musical, interessada em compreender:
#
# >- ***Quais características tornam músicas e artistas mais populares ao longo do tempo, e como esses padrões podem apoiar decisões de marketing, curadoria, produto e investimento musical?***
#
# ---
#
# </font></div>

# %% [markdown]
# <div style="background-color:#f3f2ee">
#
# <font size="4" color='#CC403E'><strong>📌 Papel deste notebook no projeto</strong></font>
#
# <font size="2" color='#66666'>
#
# > - Este notebook representa a fase de **Business Understanding** dentro do framework **CRISP-DM+**, funcionando como o contrato analítico inicial do projeto.
#
# >- Antes de carregar arquivos CSV, gerar gráficos ou aplicar estatísticas, é necessário compreender:
#     - ***qual problema de negócio está sendo investigado;***
#     - ***quais decisões podem ser apoiadas pelos dados;***
#     - ***quais stakeholders se beneficiam da análise;***
#     - ***quais hipóteses serão exploradas;***
#     - ***quais critérios indicarão sucesso analítico;***
#     - ***quais limitações precisam ser reconhecidas desde o início.***
#
# >- Essa abordagem reforça que uma EDA profissional não começa pelos gráficos, mas sim pela formulação correta do problema.
#
# ---
#
# </font></div>

# %% [markdown]
# <div style="background-color:#f3f2ee">
#
# <font size="4" color='#CC403E'><strong>📌 1. Objetivo</strong></font>
#
# <font size="2" color='#66666'>
#
# >- Apresentar a visão executiva inicial do projeto, posicionando a análise exploratória como uma entrega orientada a negócio, portfólio e preparação para futuras soluções de dados.
#
# >- **Ações realizadas**
#     - *o posicionamento do projeto;*
#     - *a motivação analítica;*
#     - *o papel do notebook dentro do ciclo CRISP-DM+;*
#     - *a intenção de transformar a EDA em uma entrega profissional;*
#     - *a conexão entre análise exploratória, tomada de decisão e evolução para modelagem.*
#
# >- **Justificativa técnica**
#     - Projetos de dados bem estruturados precisam partir de um entendimento claro do problema antes da manipulação dos dados.
#     - Essa etapa reduz o risco de análises desconectadas do negócio, evita gráficos sem finalidade analítica
#         - e direciona as próximas fases do projeto para perguntas relevantes, hipóteses testáveis e entregáveis úteis.
#     - No contexto deste projeto, o entendimento inicial é especialmente importante porque a popularidade musical pode ser influenciada por múltiplos fatores,
#         - como artista, período, atributos sonoros, tendências culturais, comportamento de consumo e dinâmica das plataformas de streaming.
#
# >- **Resultados esperados**
#     - Ao final desta célula, espera-se estabelecer uma base narrativa clara para o projeto, permitindo que as próximas etapas avancem com foco em:
#         - entendimento do mercado musical;
#         - definição da dor de negócio;
#         - formulação de perguntas analíticas;
#         - construção de hipóteses;
#         - avaliação dos dados disponíveis;
#         - preparação para EDA;
#         - planejamento de evolução para modelos e produto de dados.
#
# >- **Resumo executivo inicial**
#     - O projeto **Spotify Global Music Intelligence** será conduzido como uma entrega analítica de mercado, com foco em transformar dados musicais em conhecimento acionável.
#     - A primeira fase buscará compreender o problema, estruturar hipóteses e preparar o caminho para uma EDA robusta.
#     - As fases seguintes irão avançar para entendimento dos dados, qualidade, preparação, exploração visual, insights executivos e recomendações para futuras soluções preditivas.
#     - Este notebook, portanto, inicia a jornada do projeto como uma peça estratégica de portfólio, demonstrando raciocínio analítico, visão de negócio e maturidade metodológica.
#
# ---
#
# </font></div>

# %% [markdown]
# <div style="background-color:#f3f2ee">
#
# ## <font size="3" color='#FF5733'><strong>📚 Instalando e Carregando os Pacotes</strong></font>
#
# <font size="2" color='#66666'></font></div>

# %%
#!uv pip install watermark -q -U

# %%
from pathlib import Path

# %%
PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()

DATA_DIR = PROJECT_ROOT / "data"
RAW_DIR = DATA_DIR / "00_raw"
BRONZE_DIR = DATA_DIR / "01_bronze"
SILVER_DIR = DATA_DIR / "02_silver"
GOLD_DIR = DATA_DIR / "03_gold"

REPORTS_DIR = PROJECT_ROOT / "reports"
FIGURES_DIR = REPORTS_DIR / "figures"
HTML_DIR = REPORTS_DIR / "html"

PROJECT_ROOT
# Out:
# WindowsPath('D:/_DS-Projects/Data-Science/spotify-global-music-intelligence')

# %%
# Versões dos pacotes usados neste jupyter notebook
# %reload_ext watermark
# %watermark -a "RobertoSSoares-LfLngLrnng"
# Out:
# Author: RobertoSSoares-LfLngLrnng

# %% [markdown]
# <div style="background-color:#f3f2ee">
#
# <font size="4" color='#CC403E'><strong>📌 2. Contexto de mercado e motivação do projeto</strong></font>
#
# <font size="2" color='#66666'></font></div>

# %% [markdown]
# <div style="background-color:#f3f2ee">
#
# <font size="3" color='#CC403E'><strong>📌 2.1 Contexto geral</strong></font>
#
# <font size="2" color='#66666'>
#
# >- O mercado musical passou por uma transformação significativa com a consolidação das plataformas de streaming.
#
# >- Nesse ambiente, músicas, artistas, álbuns e playlists passaram a gerar grandes volumes de dados comportamentais,
#     - permitindo que decisões antes fortemente baseadas em intuição também sejam apoiadas por evidências quantitativas.
#
# >- Plataformas como o Spotify concentram informações relevantes sobre faixas, artistas, popularidade, datas de lançamento, atributos musicais e padrões de consumo.
#
# >- Esses dados podem ser explorados para compreender como determinadas músicas se destacam, como artistas evoluem ao longo do tempo
#     - e quais características podem estar associadas ao sucesso comercial de uma faixa.
#
# >- No contexto deste projeto, a análise exploratória de dados será utilizada como uma etapa estratégica para transformar dados musicais em conhecimento acionável.
#
# </font></div>

# %% [markdown]
# <div style="background-color:#f3f2ee">
#
# <font size="3" color='#CC403E'><strong>📌 2.2 Cenário fictício de negócio</strong></font>
#
# <font size="2" color='#66666'>
#
# >- Para tornar o projeto mais próximo de uma entrega real de mercado, será adotado o seguinte cenário fictício:
#     - A empresa **SoundWave Analytics** é uma consultoria especializada em inteligência musical e análise de dados para o setor de entretenimento.
#     - Seus clientes incluem gravadoras, equipes de marketing musical, curadores editoriais, gestores de artistas e times de produto de plataformas digitais.
#
# >- A empresa foi contratada para analisar um conjunto histórico de dados do Spotify com registros entre **2009 e 2025**,
#     - buscando entender padrões de popularidade,
#     - evolução temporal de músicas,
#     - comportamento de artistas
#     - e possíveis oportunidades para construção futura de modelos preditivos.
#
# </font></div>

# %% [markdown]
# <div style="background-color:#f3f2ee">
#
# <font size="3" color='#CC403E'><strong>📌 2.3 Problema observado no mercado</strong></font>
#
# <font size="2" color='#66666'>
#
# >- Apesar do avanço das plataformas digitais, muitas decisões no mercado musical ainda são influenciadas por fatores subjetivos,
#     - como percepção de tendência,
#     - reputação do artista,
#     - experiência de produtores,
#     - engajamento momentâneo em redes sociais ou desempenho isolado em rankings.
#
# >- Essas informações são importantes, mas podem ser insuficientes quando analisadas sem uma base estruturada de dados.
#
# >- Alguns desafios recorrentes incluem:
#     - *dificuldade de identificar padrões objetivos em músicas populares;*
#     - *baixa visibilidade sobre mudanças de tendência ao longo dos anos;*
#     - *decisões de marketing baseadas apenas em rankings agregados;*
#     - *ausência de critérios quantitativos para comparar artistas e faixas;*
#     - *dificuldade de antecipar quais músicas possuem maior potencial de destaque;*
#     - *pouca integração entre análise histórica, curadoria e estratégia comercial.*
#
# </font></div>

# %% [markdown]
# <div style="background-color:#f3f2ee">
#
# <font size="3" color='#CC403E'><strong>📌 2.4 Motivação analítica</strong></font>
#
# <font size="2" color='#66666'>
#
# >- A motivação deste projeto é investigar se os dados musicais disponíveis permitem responder perguntas relevantes para o negócio, como:
#     - *Quais artistas apresentam maior recorrência de popularidade?*
#     - *A popularidade média das músicas varia ao longo dos anos?*
#     - *Existem diferenças entre músicas populares antigas e recentes?*
#     - *Determinados atributos musicais aparecem com mais frequência em faixas populares?*
#     - *É possível criar uma base analítica para futuros modelos de previsão de popularidade?*
#     - *O dataset possui qualidade suficiente para sustentar uma análise confiável?*
#
# >- Essas perguntas reforçam o papel da EDA como uma etapa de descoberta, diagnóstico e formulação de caminhos analíticos.
#
# </font></div>

# %% [markdown]
# <div style="background-color:#f3f2ee">
#
# <font size="3" color='#CC403E'><strong>📌 2.5 Relação com EDA profissional</strong></font>
#
# <font size="2" color='#66666'>
#
# >- Neste projeto, a EDA será conduzida com foco em três dimensões:
#
# | Dimensão | Foco da análise |
# |---|---|
# | Técnica | Estrutura, tipos de dados, nulos, duplicidades, cardinalidade e consistência |
# | Analítica | Distribuições, relações entre variáveis, padrões temporais e hipóteses |
# | Executiva | Insights, recomendações, limitações e oportunidades para tomada de decisão |
#
# >- Essa abordagem evita que a análise exploratória se limite à geração de gráficos.
# >- O objetivo é construir uma narrativa analítica que conecte dados, negócio e próximos passos.
#
# </font></div>

# %% [markdown]
# <div style="background-color:#f3f2ee">
#
# <font size="3" color='#CC403E'><strong>📌 2.6 Conexão com o ciclo do projeto</strong></font>
#
# <font size="2" color='#66666'>
#
# >- O contexto de mercado definido nesta célula orientará as próximas etapas do projeto:
#     1. definição clara da dor de negócio;
#     2. formulação dos objetivos analíticos;
#     3. identificação dos stakeholders;
#     4. criação de perguntas de negócio;
#     5. construção de hipóteses;
#     6. avaliação da qualidade dos dados;
#     7. desenvolvimento da EDA;
#     8. geração de recomendações;
#     9. preparação para modelagem futura.
#
# >- Dessa forma, o projeto será conduzido como uma entrega analítica estruturada, com foco em valor de negócio e potencial de evolução para produto de dados.
#
# </font></div>

# %% [markdown]
# <div style="background-color:#f3f2ee">
#
# <font size="3" color='#CC403E'><strong>📌 2.7 Resultado esperado desta etapa</strong></font>
#
# <font size="2" color='#66666'>
#
# >- Ao final desta etapa, espera-se ter uma visão clara do contexto em que o projeto está inserido,
#     - demonstrando por que a análise de dados é relevante para o mercado musical
#     - e como a EDA pode apoiar decisões mais bem fundamentadas.
#
# >- Este contexto servirá como base para a próxima etapa: a definição formal da dor de negócio.
#
# ---
# </font></div>

# %% [markdown]
# <div style="background-color:#f3f2ee">
#
# <font size="4" color='#CC403E'><strong>📌 3. Dor de negócio e problema analítico</strong></font>
#
# <font size="2" color='#66666'></font></div>

# %% [markdown]
# <div style="background-color:#f3f2ee">
#
# <font size="3" color='#CC403E'><strong>📌 3.1 Dor central do negócio</strong></font>
#
# <font size="2" color='#66666'>
#
# >- A principal dor de negócio deste projeto está relacionada à dificuldade de transformar dados musicais em decisões estratégicas, mensuráveis e replicáveis.
#
# >- No mercado musical, decisões sobre investimento em artistas, promoção de faixas, posicionamento de campanhas, curadoria de playlists
#     - e identificação de tendências frequentemente dependem de sinais fragmentados,
#     - como rankings, percepção de popularidade, engajamento em redes sociais e experiência subjetiva de profissionais do setor.
#
# >- Embora esses sinais sejam relevantes, eles nem sempre oferecem uma visão estruturada sobre os fatores que explicam a popularidade musical ao longo do tempo.
#
# >- A dor central pode ser sintetizada da seguinte forma:
#     - Como identificar, com base em dados históricos do Spotify, quais padrões estão associados à popularidade de músicas e artistas,
#         - permitindo apoiar decisões de marketing, curadoria, produto e investimento musical?
#
# </font></div>

# %% [markdown]
# <div style="background-color:#f3f2ee">
#
# <font size="3" color='#CC403E'><strong>📌 3.2 Problemas enfrentados pelos stakeholders</strong></font>
#
# <font size="2" color='#66666'>
#
# >- A ausência de uma análise estruturada pode gerar diferentes impactos para os stakeholders envolvidos.
#
# | Stakeholder | Dor observada | Consequência potencial |
# |---|---|---|
# | Gravadoras | Dificuldade em priorizar artistas e faixas com maior potencial | Investimentos promocionais mal direcionados |
# | Marketing musical | Baixa clareza sobre perfis de músicas populares | Campanhas genéricas e pouco segmentadas |
# | Curadoria editorial | Dependência excessiva de rankings e percepção subjetiva | Playlists menos alinhadas a padrões reais de consumo |
# | Gestores de artistas | Falta de comparação analítica com outros artistas | Estratégias de posicionamento menos precisas |
# | Times de produto | Pouca exploração histórica de tendências musicais | Recomendações e experiências menos contextualizadas |
# | Cientistas de dados | Ausência de base analítica confiável para modelagem | Modelos frágeis ou desconectados do negócio |
#
# </font></div>

# %% [markdown]
# <div style="background-color:#f3f2ee">
#
# <font size="3" color='#CC403E'><strong>📌 3.3 Problema de negócio</strong></font>
#
# <font size="2" color='#66666'>
#
# >- O problema de negócio pode ser definido como:
#     - A empresa precisa compreender quais características, padrões temporais e comportamentos de artistas estão associados à popularidade musical no Spotify,
#         - para apoiar decisões mais assertivas em marketing, curadoria, produto e desenvolvimento de modelos analíticos.
#
# >- Essa definição posiciona o projeto como uma investigação orientada a decisão, e não apenas como uma exploração técnica do dataset.
#
# </font></div>

# %% [markdown]
# <div style="background-color:#f3f2ee">
#
# <font size="3" color='#CC403E'><strong>📌 3.4 Problema analítico</strong></font>
#
# <font size="2" color='#66666'>
#
# >- Do ponto de vista analítico, o problema pode ser traduzido para a seguinte pergunta:
#     - Quais variáveis, padrões e relações presentes no dataset Spotify Global Music Dataset (2009–2025) ajudam a explicar diferenças de popularidade entre músicas, artistas e períodos?
#
# >- Essa pergunta será explorada inicialmente por meio de EDA, considerando:
#     - *análise da estrutura dos dados;*
#     - *avaliação da qualidade das variáveis;*
#     - *identificação de nulos, duplicidades e inconsistências;*
#     - *distribuição da popularidade;*
#     - *evolução temporal das músicas;*
#     - *comparação entre artistas e faixas;*
#     - *análise de atributos musicais;*
#     - *investigação de correlações;*
#     - *identificação de padrões relevantes para modelagem futura.*
#
# </font></div>

# %% [markdown]
# <div style="background-color:#f3f2ee">
#
# <font size="3" color='#CC403E'><strong>📌 3.5 Riscos de não resolver o problema</strong></font>
#
# <font size="2" color='#66666'>
#
# > - Caso a empresa não avance em uma abordagem orientada por dados, alguns riscos permanecem:
#
# | Risco | Impacto |
# |---|---|
# | Decisões baseadas apenas em intuição | Maior chance de erro estratégico |
# | Baixa compreensão sobre tendências históricas | Dificuldade de antecipar mudanças no mercado |
# | Campanhas pouco segmentadas | Menor eficiência em marketing |
# | Falta de critérios para comparar artistas | Priorização subjetiva de investimentos |
# | Ausência de base preparada para modelos | Dificuldade de evoluir para soluções preditivas |
# | Baixa rastreabilidade analítica | Menor confiança nas recomendações geradas |
#
# </font></div>

# %% [markdown]
# <div style="background-color:#f3f2ee">
#
# <font size="3" color='#CC403E'><strong>📌 3.6 Oportunidade analítica</strong></font>
#
# <font size="2" color='#66666'>
#
# >- A análise exploratória pode transformar esse cenário ao oferecer uma visão estruturada sobre:
#     - *quais artistas aparecem com maior força no dataset;*
#     - *quais faixas concentram maior popularidade;*
#     - *como a popularidade varia ao longo do tempo;*
#     - *quais atributos musicais apresentam relação com popularidade;*
#     - *quais períodos possuem perfis musicais distintos;*
#     - *quais variáveis podem ser úteis em uma futura etapa de modelagem;*
#     - *quais limitações precisam ser consideradas antes de produzir recomendações.*
#
# >- Assim, a EDA passa a funcionar como uma etapa de diagnóstico estratégico, reduzindo incertezas e criando uma ponte entre dados brutos e decisões de negócio.
#
# </font></div>

# %% [markdown]
# <div style="background-color:#f3f2ee">
#
# <font size="3" color='#CC403E'><strong>📌 3.7 Delimitação do problema nesta fase</strong></font>
#
# <font size="2" color='#66666'>
#
# >- Nesta primeira fase, o projeto não buscará construir imediatamente um modelo preditivo.
#
# >- O foco será compreender os dados, validar a qualidade da base e identificar padrões relevantes.
# >- A modelagem será considerada uma etapa posterior, dependente da maturidade analítica construída durante a EDA.
#
# >Portanto, a entrega desta fase será concentrada em:
#
# | Frente | Entrega esperada |
# |---|---|
# | Negócio | Clareza sobre a dor e as perguntas relevantes |
# | Dados | Diagnóstico de estrutura, qualidade e limitações |
# | EDA | Identificação de padrões, tendências e relações |
# | Decisão | Geração de insights executivos |
# | Futuro ML | Indicação de caminhos possíveis para modelagem |
#
# </font></div>

# %% [markdown]
# <div style="background-color:#f3f2ee">
#
# <font size="3" color='#CC403E'><strong>📌 3.8 Resultado esperado desta etapa</strong></font>
#
# <font size="2" color='#66666'>
#
# >- Ao final desta etapa, espera-se ter uma definição clara do problema de negócio e de sua tradução analítica.
#
# >- Essa definição será usada como referência para as próximas células do notebook, especialmente na formulação dos objetivos do projeto,
#     - stakeholders, perguntas analíticas, hipóteses e critérios de sucesso.
#
# ---
# </font></div>

# %% [markdown]
# <div style="background-color:#f3f2ee">
#
# <font size="4" color='#CC403E'><strong>📌 4. Objetivos do projeto</strong></font>
#
# <font size="2" color='#66666'></font></div>

# %% [markdown]
# <div style="background-color:#f3f2ee">
#
# <font size="3" color='#CC403E'><strong>📌 4.1 Objetivo principal</strong></font>
#
# <font size="2" color='#66666'>
#
# >- O objetivo principal deste projeto é construir uma análise exploratória de dados profissional sobre o **Spotify Global Music Dataset (2009–2025)**,
#     - com foco em identificar padrões de popularidade musical, evolução temporal de artistas e faixas,
#     - características associadas ao desempenho das músicas e oportunidades para futuras soluções analíticas e preditivas.
#
# >- A análise será conduzida com uma abordagem orientada a negócio, buscando transformar dados musicais em conhecimento acionável para apoiar decisões de marketing,
#     - curadoria, produto, investimento artístico e desenvolvimento de modelos de machine learning.
#
# </font></div>

# %% [markdown]
# <div style="background-color:#f3f2ee">
#
# <font size="3" color='#CC403E'><strong>📌 4.2 Objetivo executivo</strong></font>
#
# <font size="2" color='#66666'>
#
# >- Do ponto de vista executivo, o projeto busca responder à seguinte pergunta:
#     - Como os dados históricos do Spotify podem ajudar a compreender padrões de popularidade musical e apoiar decisões estratégicas no mercado de streaming?
#
# >- Essa pergunta orienta a entrega para além da exploração técnica, conectando a EDA com possíveis decisões de negócio.
#
# </font></div>

# %% [markdown]
# <div style="background-color:#f3f2ee">
#
# <font size="3" color='#CC403E'><strong>📌 4.3 Objetivos específicos</strong></font>
#
# <font size="2" color='#66666'>
#
# - Os objetivos específicos do projeto estão organizados em seis frentes principais:
#
# | Frente | Objetivo específico |
# |---|---|
# | Negócio | Compreender a dor do mercado musical relacionada à identificação de tendências, popularidade e potencial comercial de faixas |
# | Dados | Avaliar a estrutura, granularidade, qualidade e limitações dos arquivos disponíveis |
# | Qualidade | Identificar nulos, duplicidades, inconsistências, problemas de tipo e possíveis limitações analíticas |
# | EDA | Explorar distribuições, rankings, padrões temporais, relações entre variáveis e comportamento de artistas |
# | Insights | Traduzir achados técnicos em interpretações executivas e recomendações iniciais |
# | Futuro ML | Preparar o caminho para modelos de previsão de popularidade, classificação de potencial de hit ou segmentação musical |
#
# </font></div>

# %% [markdown]
# <div style="background-color:#f3f2ee">
#
# <font size="3" color='#CC403E'><strong>📌 4.4 Objetivos técnicos</strong></font>
#
# <font size="2" color='#66666'>
#
# >- Do ponto de vista técnico, o projeto deverá:
#     - *carregar e inspecionar os arquivos originais do dataset;*
#     - *avaliar a consistência entre os arquivos `spotify_data_clean.csv` e `track_data_final.csv`;*
#     - *padronizar nomes de colunas;*
#     - *verificar tipos de dados;*
#     - *identificar variáveis numéricas, categóricas e temporais;*
#     - *avaliar valores ausentes;*
#     - *identificar registros duplicados;*
#     - *criar uma visão unificada dos dados quando tecnicamente viável;*
#     - *salvar bases intermediárias em formato Parquet;*
#     - *gerar tabelas analíticas em camadas Bronze, Silver e Gold;*
#     - *produzir visualizações relevantes para análise exploratória;*
#     - *documentar decisões técnicas tomadas durante o processo.*
#
# </font></div>

# %% [markdown]
# <div style="background-color:#f3f2ee">
#
# <font size="3" color='#CC403E'><strong>📌 4.5 Objetivos analíticos</strong></font>
#
# <font size="2" color='#66666'>
#
# >- Do ponto de vista analítico, o projeto deverá investigar:
#     - *distribuição da popularidade das músicas;*
#     - *artistas com maior presença e maior popularidade média;*
#     - *faixas mais populares no período analisado;*
#     - *evolução temporal da popularidade;*
#     - *diferenças entre músicas antigas e recentes;*
#     - *concentração de popularidade por artista;*
#     - *possíveis relações entre atributos musicais e popularidade;*
#     - *presença de outliers;*
#     - *correlações entre variáveis numéricas;*
#     - *grupos ou perfis musicais com comportamento semelhante;*
#     - *sinais úteis para futuras etapas de feature engineering e modelagem.*
#
# </font></div>

# %% [markdown]
# <div style="background-color:#f3f2ee">
#
# <font size="3" color='#CC403E'><strong>📌 4.6 Objetivos de negócio</strong></font>
#
# <font size="2" color='#66666'>
#
# >- Do ponto de vista de negócio, a análise deverá apoiar decisões relacionadas a:
#
# | Decisão | Como a análise pode apoiar |
# |---|---|
# | Priorização de artistas | Identificando artistas com popularidade recorrente ou trajetória relevante |
# | Curadoria de playlists | Revelando padrões de faixas populares e perfis musicais predominantes |
# | Marketing musical | Indicando características associadas a músicas com maior alcance |
# | Estratégia de lançamento | Comparando padrões entre períodos históricos |
# | Produto e recomendação | Sugerindo variáveis úteis para segmentação e recomendação futura |
# | Investimento musical | Criando evidências para reduzir subjetividade na priorização de faixas e artistas |
#
# </font></div>

# %% [markdown]
# <div style="background-color:#f3f2ee">
#
# <font size="3" color='#CC403E'><strong>📌 4.7 Objetivos de portfólio</strong></font>
#
# <font size="2" color='#66666'>
#
# >- Como projeto de portfólio, esta entrega também deverá demonstrar domínio em:
#     - *estruturação de projeto de dados;*
#     - *raciocínio de negócio;*
#     - *aplicação do CRISP-DM+;*
#     - *organização em camadas de dados;*
#     - *boas práticas de notebooks;*
#     - *análise exploratória profissional;*
#     - *storytelling analítico;*
#     - *interpretação executiva;*
#     - *preparação para machine learning;*
#     - *documentação clara e reutilizável.*
#
# >- O objetivo é construir uma peça de portfólio que comunique maturidade técnica e capacidade de transformar dados em decisão.
#
# </font></div>

# %% [markdown]
# <div style="background-color:#f3f2ee">
#
# <font size="3" color='#CC403E'><strong>📌 4.8 O que este projeto não pretende resolver nesta fase</strong></font>
#
# <font size="2" color='#66666'>
#
# >- Nesta fase inicial, o projeto não tem como objetivo:
#     - *construir um modelo preditivo final;*
#     - *realizar deploy de API;*
#     - *criar dashboard em produção;*
#     - *consumir diretamente a API do Spotify;*
#     - *inferir causalidade entre atributos musicais e popularidade;*
#     - *afirmar que determinado atributo musical causa sucesso comercial;*
#     - *substituir decisões humanas de curadoria ou estratégia musical.*
#
# >- A proposta desta etapa é criar uma base sólida de entendimento e exploração, deixando a modelagem e a produção para fases posteriores.
#
# </font></div>

# %% [markdown]
# <div style="background-color:#f3f2ee">
#
# <font size="3" color='#CC403E'><strong>📌 4.9 Resultado esperado desta etapa</strong></font>
#
# <font size="2" color='#66666'>
#
# >- Ao final desta etapa, espera-se ter uma definição clara dos objetivos do projeto em diferentes níveis:
#     - *objetivo principal;*
#     - *objetivo executivo;*
#     - *objetivos técnicos;*
#     - *objetivos analíticos;*
#     - *objetivos de negócio;*
#     - *objetivos de portfólio;*
#     - *delimitação do que está fora do escopo inicial.*
#
# >- Essa definição servirá como guia para as próximas etapas do notebook, especialmente na identificação dos stakeholders, perguntas analíticas, hipóteses e critérios de sucesso.
#
# ---
# </font></div>

# %% [markdown]
# <div style="background-color:#f3f2ee">
#
# <font size="4" color='#CC403E'><strong>📌 5. Stakeholders e usuários da análise</strong></font>
#
# <font size="2" color='#66666'></font></div>

# %% [markdown]
# <div style="background-color:#f3f2ee">
#
# <font size="3" color='#CC403E'><strong>📌 5.1 Visão geral</strong></font>
#
# <font size="2" color='#66666'>
#
# >- Um projeto de dados orientado a negócio precisa identificar claramente quem utilizará os resultados da análise e quais decisões poderão ser apoiadas pelos dados.
#
# >- No contexto do projeto **Spotify Global Music Intelligence**, os stakeholders representam diferentes áreas interessadas em compreender padrões
#     - de popularidade musical, evolução de artistas, comportamento de faixas e oportunidades para futuras soluções analíticas.
#
# >- A identificação desses públicos ajuda a direcionar as perguntas analíticas, priorizar métricas relevantes e traduzir os achados técnicos em recomendações úteis.
#
# </font></div>

# %% [markdown]
# <div style="background-color:#f3f2ee">
#
# <font size="3" color='#CC403E'><strong>📌 5.2 Stakeholders principais</strong></font>
#
# <font size="2" color='#66666'>
#
# | Stakeholder | Papel no negócio | Interesse principal |
# |---|---|---|
# | Diretoria de gravadora | Define investimentos em artistas, campanhas e lançamentos | Identificar artistas e faixas com maior potencial comercial |
# | Marketing musical | Planeja campanhas de divulgação e posicionamento | Entender características de músicas populares para segmentar ações |
# | Curadoria editorial | Organiza playlists e recomendações musicais | Identificar padrões de faixas com alto engajamento e popularidade |
# | Gestores de artistas | Apoiam posicionamento e desenvolvimento de carreira | Comparar desempenho de artistas ao longo do tempo |
# | Time de produto | Desenvolve experiências digitais e sistemas de recomendação | Explorar variáveis úteis para personalização e descoberta musical |
# | Cientistas de dados | Constroem análises, features e modelos preditivos | Avaliar qualidade dos dados e viabilidade de modelagem |
# | Analistas de negócio | Traduzem dados em relatórios e recomendações | Gerar insights claros para apoiar decisões estratégicas |
#
# </font></div>

# %% [markdown]
# <div style="background-color:#f3f2ee">
#
# <font size="3" color='#CC403E'><strong>📌 5.3 Necessidades analíticas por stakeholder</strong></font>
#
# <font size="2" color='#66666'>
#
# >- Cada stakeholder possui uma necessidade diferente em relação aos dados.
#
# | Stakeholder | Necessidade analítica | Exemplo de pergunta |
# |---|---|---|
# | Diretoria de gravadora | Priorização de investimento | Quais artistas apresentam maior recorrência de popularidade? |
# | Marketing musical | Segmentação de campanhas | Quais características aparecem em faixas mais populares? |
# | Curadoria editorial | Seleção de músicas e playlists | Quais faixas ou perfis musicais se destacam em determinados períodos? |
# | Gestores de artistas | Posicionamento competitivo | Como determinado artista se compara com outros artistas populares? |
# | Time de produto | Recomendação e descoberta | Quais atributos podem apoiar agrupamento ou recomendação musical? |
# | Cientistas de dados | Preparação para ML | O dataset possui variáveis consistentes para modelagem futura? |
# | Analistas de negócio | Comunicação executiva | Quais insights podem ser traduzidos em recomendações práticas? |
#
# </font></div>

# %% [markdown]
# <div style="background-color:#f3f2ee">
#
# <font size="3" color='#CC403E'><strong>📌 5.4 Como a EDA gera valor para cada público</strong></font>
#
# <font size="2" color='#66666'>
#
# >- A EDA será usada como ponte entre os dados brutos e as decisões dos stakeholders.
#
# | Público | Valor gerado pela EDA |
# |---|---|
# | Liderança executiva | Visão consolidada sobre tendências e oportunidades |
# | Marketing | Evidências para melhorar campanhas e segmentações |
# | Curadoria | Identificação de padrões musicais relevantes |
# | Produto | Base para futuras funcionalidades analíticas |
# | Dados e Analytics | Diagnóstico técnico e base preparada para modelagem |
# | Portfólio profissional | Demonstração de raciocínio analítico orientado a negócio |
#
# </font></div>

# %% [markdown]
# <div style="background-color:#f3f2ee">
#
# <font size="3" color='#CC403E'><strong>📌 5.5 Usuários finais da entrega</strong></font>
#
# <font size="2" color='#66666'>
#
# >- Além dos stakeholders de negócio, também existem usuários finais da entrega analítica.
#
# | Usuário final | Uso esperado da análise |
# |---|---|
# | Recrutadores técnicos | Avaliar domínio de EDA, Python, organização de projeto e interpretação de dados |
# | Gestores de dados | Avaliar maturidade na condução de projeto analítico |
# | Profissionais de negócio | Entender como dados podem apoiar decisões no setor musical |
# | Comunidade de dados | Usar o projeto como referência de EDA estruturada |
# | O próprio autor do projeto | Reutilizar o framework em novos projetos de portfólio |
#
# </font></div>

# %% [markdown]
# <div style="background-color:#f3f2ee">
#
# <font size="3" color='#CC403E'><strong>📌 5.6 Decisões que poderão ser apoiadas</strong></font>
#
# <font size="2" color='#66666'>
#
# >- A análise exploratória deste projeto poderá apoiar decisões como:
#     - *priorizar artistas ou faixas para análise mais aprofundada;*
#     - *identificar períodos de maior concentração de popularidade;*
#     - *comparar músicas recentes e antigas;*
#     - *entender padrões de popularidade por artista;*
#     - *avaliar se atributos musicais têm relação com popularidade;*
#     - *definir variáveis candidatas para feature engineering;*
#     - *planejar modelos futuros de previsão ou classificação;*
#     - *construir uma narrativa executiva para apresentação do projeto.*
#
# </font></div>

# %% [markdown]
# <div style="background-color:#f3f2ee">
#
# <font size="3" color='#CC403E'><strong>📌 5.7 Riscos de desalinhamento com stakeholders</strong></font>
#
# <font size="2" color='#66666'>
#
# >- Caso os stakeholders não sejam considerados desde o início, o projeto pode gerar análises tecnicamente corretas, mas pouco úteis para decisão.
#
# | Risco | Consequência |
# |---|---|
# | Foco excessivo em gráficos sem pergunta de negócio | Análise visualmente interessante, mas sem direção |
# | Métricas desalinhadas com a decisão | Baixa utilidade executiva |
# | Linguagem técnica demais | Dificuldade de comunicação com áreas de negócio |
# | Ausência de critérios de sucesso | Dificuldade de avaliar se a entrega gerou valor |
# | Falta de priorização | EDA extensa, porém dispersa |
#
# </font></div>

# %% [markdown]
# <div style="background-color:#f3f2ee">
#
# <font size="3" color='#CC403E'><strong>📌 5.8 Estratégia de comunicação dos resultados</strong></font>
#
# <font size="2" color='#66666'>
#
# >- Os resultados da análise deverão ser comunicados em diferentes níveis de profundidade:
#
# | Nível | Público | Forma de comunicação |
# |---|---|---|
# | Executivo | Liderança, marketing e curadoria | Resumos, rankings, recomendações e insights |
# | Técnico | Cientistas e analistas de dados | Notebooks, diagnósticos, tabelas e gráficos |
# | Portfólio | Recrutadores e comunidade | README, HTML exportado, storytelling e visualizações |
# | Produto | Times digitais | Possíveis features, segmentações e oportunidades futuras |
#
# </font></div>

# %% [markdown]
# <div style="background-color:#f3f2ee">
#
# <font size="3" color='#CC403E'><strong>📌 5.9 Resultado esperado desta etapa</strong></font>
#
# <font size="2" color='#66666'>
#
# >- Ao final desta etapa, espera-se ter clareza sobre quem se beneficia da análise, quais decisões podem ser apoiadas e como os resultados deverão ser comunicados.
#
# >- Essa definição será usada como base para a próxima etapa do notebook: a formulação das perguntas analíticas.
#
# ---
# </font></div>

# %% [markdown]
# <div style="background-color:#f3f2ee">
#
# <font size="4" color='#CC403E'><strong>📌 6. Perguntas analíticas do projeto</strong></font>
#
# <font size="2" color='#66666'></font></div>

# %% [markdown]
# <div style="background-color:#f3f2ee">
#
# <font size="3" color='#CC403E'><strong>📌 6.1 Visão geral</strong></font>
#
# <font size="2" color='#66666'>
#
# >- As perguntas analíticas são responsáveis por transformar a dor de negócio em caminhos objetivos de investigação.
#
# >- No projeto **Spotify Global Music Intelligence**, essas perguntas irão orientar as próximas etapas da análise, especialmente o entendimento dos dados,
#     - a avaliação de qualidade, a exploração visual, a construção de hipóteses e a definição de possíveis variáveis para futuras etapas de modelagem.
#
# >- Uma boa pergunta analítica deve conectar três elementos:
#     1. *uma necessidade de negócio;*
#     2. *uma possibilidade de investigação com dados;*
#     3. *uma decisão ou interpretação que possa ser gerada a partir da análise.*
#
# </font></div>

# %% [markdown]
# <div style="background-color:#f3f2ee">
#
# <font size="3" color='#CC403E'><strong>📌 6.2 Pergunta central do projeto</strong></font>
#
# <font size="2" color='#66666'>
#
# >- A pergunta central que orienta este projeto é:
#     - Quais fatores ajudam a explicar a popularidade de músicas e artistas no Spotify ao longo do tempo, e como esses padrões podem apoiar
#         - decisões de marketing, curadoria, produto e desenvolvimento de modelos preditivos?
#
# >- Essa pergunta será desdobrada em perguntas menores, mais específicas e investigáveis.
#
# </font></div>

# %% [markdown]
# <div style="background-color:#f3f2ee">
#
# <font size="3" color='#CC403E'><strong>📌 6.3 Perguntas sobre estrutura e qualidade dos dados</strong></font>
#
# <font size="2" color='#66666'>
#
# >- Antes de analisar popularidade, artistas ou tendências, é necessário avaliar se os dados disponíveis são confiáveis.
#
# | Código | Pergunta analítica | Objetivo |
# |---|---|---|
# | QD01 | Quantas linhas e colunas existem em cada arquivo do dataset? | Entender o volume inicial de dados |
# | QD02 | Os arquivos possuem a mesma estrutura de colunas? | Avaliar possibilidade de unificação |
# | QD03 | Existem colunas com nomes diferentes, mas significado semelhante? | Identificar necessidade de padronização |
# | QD04 | Quais colunas possuem valores ausentes? | Avaliar qualidade e completude |
# | QD05 | Existem registros duplicados? | Medir risco de contagem ou análise inflada |
# | QD06 | As variáveis possuem tipos de dados adequados? | Validar consistência técnica |
# | QD07 | Existem valores extremos ou inconsistentes? | Identificar possíveis outliers ou erros |
# | QD08 | O período 2009–2025 está corretamente representado? | Validar cobertura temporal |
#
# </font></div>

# %% [markdown]
# <div style="background-color:#f3f2ee">
#
# <font size="3" color='#CC403E'><strong>📌 6.4 Perguntas sobre popularidade musical</strong></font>
#
# <font size="2" color='#66666'>
#
# >- A popularidade é uma das principais variáveis de interesse do projeto.
#
# | Código | Pergunta analítica | Objetivo |
# |---|---|---|
# | QP01 | Como a popularidade das músicas está distribuída? | Entender concentração, dispersão e assimetria |
# | QP02 | Quais são as músicas mais populares do dataset? | Identificar faixas de maior destaque |
# | QP03 | Quais artistas possuem maior popularidade média? | Comparar desempenho agregado por artista |
# | QP04 | Existem artistas com alta recorrência de músicas populares? | Avaliar consistência de popularidade |
# | QP05 | A popularidade varia significativamente entre períodos? | Investigar evolução temporal |
# | QP06 | Existem músicas com popularidade muito acima do padrão? | Identificar outliers positivos |
# | QP07 | Existem músicas com baixa popularidade apesar de artistas conhecidos? | Explorar possíveis discrepâncias |
#
# </font></div>

# %% [markdown]
# <div style="background-color:#f3f2ee">
#
# <font size="3" color='#CC403E'><strong>📌 6.5 Perguntas sobre artistas</strong></font>
#
# <font size="2" color='#66666'>
#
# >- A análise por artista ajuda a entender concentração, recorrência e relevância no catálogo.
#
# | Código | Pergunta analítica | Objetivo |
# |---|---|---|
# | QA01 | Quais artistas aparecem com maior frequência no dataset? | Medir presença no catálogo |
# | QA02 | Quais artistas combinam alta frequência e alta popularidade? | Identificar relevância recorrente |
# | QA03 | Existem artistas com poucas músicas, mas alta popularidade média? | Identificar possíveis casos de alto impacto |
# | QA04 | Existem artistas com muitas músicas, mas popularidade média baixa? | Avaliar volume versus desempenho |
# | QA05 | Como a popularidade dos artistas evolui ao longo do tempo? | Identificar trajetórias e ciclos |
# | QA06 | A popularidade está concentrada em poucos artistas? | Avaliar concentração do mercado musical |
# | QA07 | Existem artistas emergentes no período mais recente? | Explorar sinais de renovação musical |
#
# </font></div>

# %% [markdown]
# <div style="background-color:#f3f2ee">
#
# <font size="3" color='#CC403E'><strong>📌 6.6 Perguntas sobre evolução temporal</strong></font>
#
# <font size="2" color='#66666'>
#
# >- Como o dataset cobre diferentes anos, a dimensão temporal será essencial para o projeto.
#
# | Código | Pergunta analítica | Objetivo |
# |---|---|---|
# | QT01 | Quantas músicas existem por ano de lançamento? | Avaliar distribuição temporal do dataset |
# | QT02 | A popularidade média muda ao longo dos anos? | Identificar tendências gerais |
# | QT03 | Existem períodos com maior concentração de músicas populares? | Comparar fases históricas |
# | QT04 | O perfil das músicas populares mudou entre 2009–2015, 2016–2020 e 2021–2025? | Investigar mudança de padrão |
# | QT05 | Músicas recentes apresentam atributos diferentes das músicas antigas? | Avaliar evolução musical |
# | QT06 | Existem anos com comportamento atípico de popularidade? | Detectar anomalias temporais |
# | QT07 | O ano de lançamento influencia a leitura da popularidade atual? | Avaliar possível viés temporal |
#
# </font></div>

# %% [markdown]
# <div style="background-color:#f3f2ee">
#
# <font size="3" color='#CC403E'><strong>📌 6.7 Perguntas sobre atributos musicais</strong></font>
#
# <font size="2" color='#66666'>
#
# > - Caso o dataset contenha atributos como energia, dançabilidade, valência, tempo, duração ou acústica, eles serão analisados como possíveis fatores associados à popularidade.
#
# | Código | Pergunta analítica | Objetivo |
# |---|---|---|
# | QM01 | Quais atributos musicais estão disponíveis no dataset? | Mapear variáveis analíticas |
# | QM02 | Como esses atributos estão distribuídos? | Entender perfil sonoro geral |
# | QM03 | Músicas mais populares possuem maior energia ou dançabilidade? | Investigar possíveis associações |
# | QM04 | Existe relação entre duração da música e popularidade? | Avaliar efeito de formato |
# | QM05 | A valência ou positividade da música varia ao longo do tempo? | Explorar mudanças de estilo |
# | QM06 | Certos atributos musicais se tornaram mais comuns em anos recentes? | Avaliar evolução sonora |
# | QM07 | Existem combinações de atributos associadas a faixas populares? | Preparar terreno para segmentação |
#
# </font></div>

# %% [markdown]
# <div style="background-color:#f3f2ee">
#
# <font size="3" color='#CC403E'><strong>📌 6.8 Perguntas sobre segmentação e perfis musicais</strong></font>
#
# <font size="2" color='#66666'>
#
# >- Além de rankings, o projeto buscará entender se existem grupos ou perfis recorrentes.
#
# | Código | Pergunta analítica | Objetivo |
# |---|---|---|
# | QS01 | Existem perfis distintos de músicas no dataset? | Identificar possíveis segmentos |
# | QS02 | Músicas populares se concentram em determinados perfis? | Relacionar grupos com desempenho |
# | QS03 | Artistas podem ser agrupados por padrão de popularidade? | Explorar segmentação por artista |
# | QS04 | Existem diferenças entre músicas modernas e clássicas/populares? | Comparar bases e períodos |
# | QS05 | É possível criar uma classificação exploratória de potencial de hit? | Preparar futura modelagem |
# | QS06 | Quais variáveis parecem mais úteis para segmentação futura? | Apoiar feature engineering |
#
# </font></div>

# %% [markdown]
# <div style="background-color:#f3f2ee">
#
# <font size="3" color='#CC403E'><strong>📌 6.9 Perguntas orientadas à modelagem futura</strong></font>
#
# <font size="2" color='#66666'>
#
# >- Embora a modelagem não seja o foco imediato desta fase, a EDA deve preparar o caminho para ela.
#
# | Código | Pergunta analítica | Objetivo |
# |---|---|---|
# | QMLO1 | A variável de popularidade pode ser usada como target? | Avaliar viabilidade preditiva |
# | QMLO2 | A popularidade deve ser tratada como regressão ou classificação? | Definir abordagem futura |
# | QMLO3 | Existem variáveis suficientes para explicar diferenças de popularidade? | Avaliar potencial de ML |
# | QMLO4 | Há risco de vazamento de informação entre variáveis? | Prevenir problemas de modelagem |
# | QMLO5 | É possível criar classes como baixa, média e alta popularidade? | Preparar classificação |
# | QMLO6 | Quais features podem ser derivadas dos dados originais? | Planejar feature engineering |
# | QMLO7 | A base possui qualidade mínima para treinar modelos? | Avaliar prontidão técnica |
#
# </font></div>

# %% [markdown]
# <div style="background-color:#f3f2ee">
#
# <font size="3" color='#CC403E'><strong>📌 6.10 Priorização inicial das perguntas</strong></font>
#
# <font size="2" color='#66666'>
#
# >- Nem todas as perguntas serão respondidas no mesmo momento. Para orientar a execução, será adotada a seguinte priorização inicial:
#
# | Prioridade | Grupo de perguntas | Justificativa |
# |---|---|---|
# | Alta | Estrutura e qualidade dos dados | Sem dados confiáveis, a EDA perde validade |
# | Alta | Popularidade musical | É o eixo central do projeto |
# | Alta | Evolução temporal | O dataset cobre diferentes períodos históricos |
# | Média | Artistas | Apoia decisões de marketing, curadoria e investimento |
# | Média | Atributos musicais | Ajuda a entender características associadas à popularidade |
# | Média | Segmentação | Prepara caminho para clusters e perfis musicais |
# | Futura | Modelagem | Será aprofundada após validação da base e da EDA |
#
# </font></div>

# %% [markdown]
# <div style="background-color:#f3f2ee">
#
# <font size="3" color='#CC403E'><strong>📌 6.11 Relação entre perguntas e próximos notebooks</strong></font>
#
# <font size="2" color='#66666'>
#
# >- As perguntas desta célula serão distribuídas ao longo dos próximos notebooks do projeto.
#
# | Notebook | Perguntas mais relacionadas |
# |---|---|
# | Notebook 01 — Data Understanding | QD01 a QD08 |
# | Notebook 02 — Data Quality and Preparation | QD03 a QD08 |
# | Notebook 03 — Exploratory Data Analysis | QP, QA, QT, QM e QS |
# | Notebook 04 — Executive Insights and Next Steps | Consolidação das respostas e recomendações |
# | Fase futura de ML | QMLO1 a QMLO7 |
#
# </font></div>

# %% [markdown]
# <div style="background-color:#f3f2ee">
#
# <font size="3" color='#CC403E'><strong>📌 6.12 Resultado esperado desta etapa</strong></font>
#
# <font size="2" color='#66666'>
#
# >- Ao final desta etapa, espera-se ter um conjunto estruturado de perguntas analíticas capazes de orientar a execução do projeto.
#
# >- Essas perguntas serão usadas como referência para:
#     - *planejar o entendimento dos dados;*
#     - *direcionar a limpeza e preparação;*
#     - *escolher visualizações adequadas;*
#     - *validar hipóteses;*
#     - *construir insights executivos;*
#     - *avaliar oportunidades de modelagem futura;*
#     - *comunicar resultados de forma clara e orientada à decisão.*
#
# ---
# </font></div>

# %% [markdown]
# <div style="background-color:#f3f2ee">
#
# <font size="4" color='#CC403E'><strong>📌 7. Hipóteses analíticas do projeto</strong></font>
#
# <font size="2" color='#66666'></font></div>

# %% [markdown]
# <div style="background-color:#f3f2ee">
#
# <font size="3" color='#CC403E'><strong>📌 7.1 Visão geral</strong></font>
#
# <font size="2" color='#66666'>
#
# >- As hipóteses analíticas representam suposições iniciais sobre o comportamento dos dados e sobre os possíveis fatores associados à popularidade musical no Spotify.
#
# >- No projeto **Spotify Global Music Intelligence**, essas hipóteses serão usadas para orientar a análise exploratória, estruturar comparações,
#     - definir visualizações e preparar a interpretação executiva dos resultados.
#
# >- É importante destacar que uma hipótese não é uma conclusão.
# >- Ela é uma afirmação inicial que deverá ser investigada com base nos dados disponíveis.
#
# >- Ao longo dos próximos notebooks, cada hipótese poderá ser:
#     - **confirmada**, quando os dados apresentarem evidências consistentes;
#     - **refutada**, quando os dados não sustentarem a suposição inicial;
#     - **parcialmente confirmada**, quando a hipótese fizer sentido apenas em determinados recortes;
#     - **inconclusiva**, quando os dados não forem suficientes para uma avaliação segura.
#
# </font></div>

# %% [markdown]
# <div style="background-color:#f3f2ee">
#
# <font size="3" color='#CC403E'><strong>📌 7.2 Papel das hipóteses no projeto</strong></font>
#
# <font size="2" color='#66666'>
#
# >- As hipóteses cumprem quatro papéis principais neste projeto:
#
# | Papel | Descrição |
# |---|---|
# | Direcionar a EDA | Evita uma exploração dispersa e sem objetivo |
# | Conectar dados ao negócio | Relaciona padrões técnicos com decisões estratégicas |
# | Apoiar storytelling | Facilita a construção de uma narrativa analítica |
# | Preparar modelagem futura | Ajuda a identificar variáveis candidatas para features |
#
# >- Essa abordagem segue o princípio de uma análise exploratória estruturada: partir do problema de negócio, formular hipóteses,
#     - entender os dados, preparar a base, visualizar padrões e extrair recomendações.
#
# </font></div>

# %% [markdown]
# <div style="background-color:#f3f2ee">
#
# <font size="3" color='#CC403E'><strong>📌 7.3 Hipóteses sobre qualidade e estrutura dos dados</strong></font>
#
# <font size="2" color='#66666'>
#
# >- Antes de analisar popularidade, artistas ou tendências, é necessário avaliar se os dados possuem qualidade suficiente para sustentar a análise.
#
# | Código | Hipótese | Como será investigada |
# |---|---|---|
# | H-DQ01 | Os dois arquivos possuem estruturas compatíveis para integração analítica. | Comparação de colunas, tipos e granularidade |
# | H-DQ02 | Existem colunas com nomes diferentes, mas conceitos equivalentes. | Análise semântica dos nomes das variáveis |
# | H-DQ03 | O dataset possui valores ausentes que podem impactar análises de popularidade e atributos musicais. | Relatório de nulos por coluna |
# | H-DQ04 | Existem registros duplicados ou quase duplicados de músicas/artistas. | Verificação por linha completa e chaves compostas |
# | H-DQ05 | Algumas variáveis precisarão de padronização antes da EDA. | Avaliação de nomes, tipos, datas e categorias |
# | H-DQ06 | A cobertura temporal 2009–2025 pode não estar uniformemente distribuída. | Contagem de registros por ano/período |
#
# </font></div>

# %% [markdown]
# <div style="background-color:#f3f2ee">
#
# <font size="3" color='#CC403E'><strong>📌 7.4 Hipóteses sobre popularidade musical</strong></font>
#
# <font size="2" color='#66666'>
#
# >- A popularidade será o principal eixo analítico do projeto.
#
# | Código | Hipótese | Racional de negócio |
# |---|---|---|
# | H-POP01 | A popularidade das músicas não está distribuída de forma uniforme. | Poucas músicas tendem a concentrar maior destaque |
# | H-POP02 | Existe concentração de músicas muito populares em determinados artistas. | Artistas consolidados podem dominar parte do catálogo |
# | H-POP03 | Músicas com popularidade muito alta representam outliers positivos. | Faixas excepcionais podem distorcer médias e rankings |
# | H-POP04 | A popularidade média varia entre diferentes períodos históricos. | O mercado musical muda com o tempo |
# | H-POP05 | Músicas recentes podem apresentar padrões diferentes das músicas antigas. | Streaming, redes sociais e consumo digital alteram dinâmica de sucesso |
# | H-POP06 | A popularidade de uma faixa não depende apenas da popularidade do artista. | Algumas músicas podem performar acima ou abaixo do padrão do artista |
#
# </font></div>

# %% [markdown]
# <div style="background-color:#f3f2ee">
#
# <font size="3" color='#CC403E'><strong>📌 7.4 Hipóteses sobre popularidade musical</strong></font>
#
# <font size="2" color='#66666'>
#
# - A popularidade será o principal eixo analítico do projeto.
#
# | Código | Hipótese | Racional de negócio |
# |---|---|---|
# | H-POP01 | A popularidade das músicas não está distribuída de forma uniforme. | Poucas músicas tendem a concentrar maior destaque |
# | H-POP02 | Existe concentração de músicas muito populares em determinados artistas. | Artistas consolidados podem dominar parte do catálogo |
# | H-POP03 | Músicas com popularidade muito alta representam outliers positivos. | Faixas excepcionais podem distorcer médias e rankings |
# | H-POP04 | A popularidade média varia entre diferentes períodos históricos. | O mercado musical muda com o tempo |
# | H-POP05 | Músicas recentes podem apresentar padrões diferentes das músicas antigas. | Streaming, redes sociais e consumo digital alteram dinâmica de sucesso |
# | H-POP06 | A popularidade de uma faixa não depende apenas da popularidade do artista. | Algumas músicas podem performar acima ou abaixo do padrão do artista |
#
# </font></div>

# %% [markdown]
# <div style="background-color:#f3f2ee">
#
# <font size="3" color='#CC403E'><strong>📌 7.5 Hipóteses sobre artistas</strong></font>
#
# <font size="2" color='#66666'>
#
# >- A análise por artista permitirá entender recorrência, concentração e trajetórias de popularidade.
#
# | Código | Hipótese | Racional de negócio |
# |---|---|---|
# | H-ART01 | Poucos artistas concentram grande parte das faixas mais populares. | Pode existir concentração de mercado |
# | H-ART02 | Existem artistas com muitas músicas, mas popularidade média moderada. | Volume de catálogo não garante alto desempenho |
# | H-ART03 | Existem artistas com poucas faixas, mas alta popularidade média. | Alguns artistas/faixas podem ter impacto concentrado |
# | H-ART04 | Certos artistas apresentam popularidade mais consistente ao longo do tempo. | Consistência pode indicar força de marca/artista |
# | H-ART05 | Artistas recentes podem apresentar padrões diferentes de artistas consolidados. | O mercado pode indicar renovação ou mudança de estilo |
# | H-ART06 | A popularidade dos artistas pode variar por período, indicando ciclos de ascensão, pico e queda. | Trajetórias musicais podem não ser lineares |
#
# </font></div>

# %% [markdown]
# <div style="background-color:#f3f2ee">
#
# <font size="3" color='#CC403E'><strong>📌 7.6 Hipóteses sobre evolução temporal</strong></font>
#
# <font size="2" color='#66666'>
#
# >- Como o dataset cobre o período de 2009 a 2025, a dimensão temporal será fundamental.
#
# | Código | Hipótese | Racional de negócio |
# |---|---|---|
# | H-TEMP01 | A quantidade de músicas por ano não é uniforme. | O dataset pode ter maior concentração em determinados períodos |
# | H-TEMP02 | A popularidade média muda ao longo dos anos. | Mudanças de consumo podem alterar padrões de sucesso |
# | H-TEMP03 | O perfil das músicas populares mudou entre 2009–2015, 2016–2020 e 2021–2025. | Diferentes ciclos do streaming podem gerar padrões distintos |
# | H-TEMP04 | Existem anos com comportamento atípico de popularidade. | Eventos de mercado ou composição do dataset podem gerar anomalias |
# | H-TEMP05 | Músicas recentes tendem a refletir tendências mais próximas do consumo atual. | O recorte de 2025 pode carregar sinais de tendência contemporânea |
# | H-TEMP06 | Músicas antigas ainda populares podem representar faixas de catálogo duradouro. | Alguns hits podem manter relevância ao longo do tempo |
#
# </font></div>

# %% [markdown]
# <div style="background-color:#f3f2ee">
#
# <font size="3" color='#CC403E'><strong>📌 7.7 Hipóteses sobre atributos musicais</strong></font>
#
# <font size="2" color='#66666'>
#
# >- Caso o dataset contenha atributos como energia, dançabilidade, valência, tempo, duração, acústica ou instrumentalidade, eles serão analisados como possíveis fatores associados à popularidade.
#
# | Código | Hipótese | Racional analítico |
# |---|---|---|
# | H-MUS01 | Músicas mais populares apresentam diferenças em atributos musicais quando comparadas às menos populares. | Atributos sonoros podem indicar padrões de preferência |
# | H-MUS02 | Faixas com maior dançabilidade podem apresentar maior popularidade média. | Músicas mais dançantes podem ter maior apelo em playlists e consumo social |
# | H-MUS03 | Faixas com maior energia podem se destacar em determinados períodos. | O perfil energético pode variar conforme tendências musicais |
# | H-MUS04 | A duração das músicas pode ter relação com popularidade. | Formatos mais curtos podem ser favorecidos em consumo digital |
# | H-MUS05 | A valência das músicas pode variar ao longo dos anos. | O tom emocional das faixas pode refletir mudanças culturais |
# | H-MUS06 | Combinações de atributos musicais podem ser mais relevantes do que atributos isolados. | Popularidade pode depender da interação entre características |
#
# </font></div>

# %% [markdown]
# <div style="background-color:#f3f2ee">
#
# <font size="3" color='#CC403E'><strong>📌 7.8 Hipóteses sobre segmentação musical</strong></font>
#
# <font size="2" color='#66666'>
#
# >- Além de rankings e estatísticas descritivas, o projeto poderá investigar perfis de músicas e artistas.
#
# | Código | Hipótese | Racional analítico |
# |---|---|---|
# | H-SEG01 | Existem grupos distintos de músicas com características semelhantes. | Atributos musicais podem formar perfis naturais |
# | H-SEG02 | Músicas populares podem se concentrar em alguns perfis específicos. | Certos padrões sonoros podem estar associados a maior desempenho |
# | H-SEG03 | Artistas podem ser agrupados por recorrência e intensidade de popularidade. | Perfis de artista podem apoiar decisões de investimento |
# | H-SEG04 | Músicas recentes e antigas podem pertencer a segmentos diferentes. | A evolução musical pode alterar o perfil dos grupos |
# | H-SEG05 | Uma segmentação exploratória pode apoiar futura classificação de potencial de hit. | Clusters podem servir como base para feature engineering |
#
# </font></div>

# %% [markdown]
# <div style="background-color:#f3f2ee">
#
# <font size="3" color='#CC403E'><strong>📌 7.9 Hipóteses sobre modelagem futura</strong></font>
#
# <font size="2" color='#66666'>
#
# >- Embora o foco atual seja EDA, algumas hipóteses ajudam a preparar o caminho para machine learning.
#
# | Código | Hipótese | Implicação futura |
# |---|---|---|
# | H-ML01 | A popularidade pode ser usada como variável alvo em uma modelagem futura. | Possível problema de regressão ou classificação |
# | H-ML02 | Será possível criar classes de popularidade como baixa, média e alta. | Caminho para classificação supervisionada |
# | H-ML03 | O dataset contém variáveis suficientes para gerar features relevantes. | Avaliação de viabilidade preditiva |
# | H-ML04 | A base precisará de tratamento antes de qualquer modelo. | Necessidade de camada Silver e feature engineering |
# | H-ML05 | Pode existir risco de vazamento de informação dependendo das variáveis disponíveis. | Exigirá cuidado na seleção de features |
# | H-ML06 | Modelos simples poderão servir como baseline antes de algoritmos mais complexos. | Comparação futura entre regressão, árvores e boosting |
#
# </font></div>

# %% [markdown]
# <div style="background-color:#f3f2ee">
#
# <font size="3" color='#CC403E'><strong>📌 7.10 Priorização das hipóteses</strong></font>
#
# <font size="2" color='#66666'>
#
# >- Nem todas as hipóteses serão investigadas com a mesma profundidade nesta fase inicial. A priorização será feita de acordo com a importância para a EDA e para a continuidade do projeto.
#
# | Prioridade | Grupo de hipóteses | Justificativa |
# |---|---|---|
# | Alta | Qualidade e estrutura dos dados | Sem dados confiáveis, as demais análises perdem validade |
# | Alta | Popularidade musical | É o eixo central do projeto |
# | Alta | Evolução temporal | O dataset cobre múltiplos anos e períodos |
# | Média | Artistas | Apoia decisões de marketing, curadoria e investimento |
# | Média | Atributos musicais | Ajuda a explicar padrões de popularidade |
# | Média | Segmentação | Prepara futura análise de perfis musicais |
# | Futura | Modelagem | Será aprofundada após a EDA e preparação dos dados |
#
# </font></div>

# %% [markdown]
# <div style="background-color:#f3f2ee">
#
# <font size="3" color='#CC403E'><strong>📌 7.11 Como as hipóteses serão avaliadas</strong></font>
#
# <font size="2" color='#66666'>
#
# >- As hipóteses serão investigadas ao longo dos próximos notebooks utilizando diferentes técnicas de análise exploratória.
#
# | Tipo de evidência | Exemplos de técnica |
# |---|---|
# | Estrutura dos dados | `shape`, tipos, colunas, amostras e chaves |
# | Qualidade dos dados | nulos, duplicados, cardinalidade e inconsistências |
# | Estatística descritiva | média, mediana, desvio padrão, quartis e percentis |
# | Distribuições | histogramas, boxplots e densidades |
# | Rankings | top músicas, top artistas e rankings por período |
# | Comparações temporais | análise por ano, período e coortes temporais |
# | Relações entre variáveis | correlação, dispersão e agrupamentos |
# | Segmentações | perfis exploratórios de músicas e artistas |
# | Interpretação executiva | síntese dos achados e recomendações |
#
# </font></div>

# %% [markdown]
# <div style="background-color:#f3f2ee">
#
# <font size="3" color='#CC403E'><strong>📌 7.12 Cuidados de interpretação</strong></font>
#
# <font size="2" color='#66666'>
#
# >- Durante a análise, será necessário evitar conclusões indevidas.
#
# >- Este projeto buscará identificar associações e padrões exploratórios, mas não afirmará causalidade sem metodologia adequada.
#
# >- Por exemplo, mesmo que músicas mais populares apresentem maior energia ou dançabilidade, isso não significa necessariamente que esses atributos causam popularidade.
#
# >- A popularidade musical pode depender de fatores externos que não estão presentes no dataset, como:
#     - *investimento em marketing;*
#     - *presença em playlists oficiais;*
#     - *base prévia de fãs;*
#     - *gravadora;*
#     - *redes sociais;*
#     - *região geográfica;*
#     - *momento cultural;*
#     - *colaborações entre artistas;*
#     - *exposição em mídia;*
#     - *algoritmo de recomendação da plataforma.*
#
# >- Portanto, as hipóteses serão avaliadas com cautela, distinguindo evidência exploratória de conclusão causal.
#
# </font></div>

# %% [markdown]
# <div style="background-color:#f3f2ee">
#
# <font size="3" color='#CC403E'><strong>📌 7.13 Resultado esperado desta etapa</strong></font>
#
# <font size="2" color='#66666'>
#
# >- Ao final desta etapa, espera-se ter um conjunto estruturado de hipóteses que oriente a execução dos próximos notebooks.
#
# > - Essas hipóteses serão usadas como referência para:
#     - *organizar o entendimento dos dados;*
#     - *priorizar análises de qualidade;*
#     - *orientar visualizações;*
#     - *interpretar padrões;*
#     - *validar ou refutar suposições iniciais;*
#     - *construir insights executivos;*
#     - *preparar futuras etapas de feature engineering e machine learning.*
#
# >- A partir deste ponto, o projeto passa a ter uma matriz analítica clara, conectando problema de negócio, perguntas investigativas, hipóteses e próximos passos de execução.
#
# ---
# </font></div>

# %% [markdown]
# <div style="background-color:#f3f2ee">
#
# <font size="4" color='#CC403E'><strong>📌 8. Critérios de sucesso do projeto</strong></font>
#
# <font size="2" color='#66666'></font></div>

# %% [markdown]
# <div style="background-color:#f3f2ee">
#
# <font size="3" color='#CC403E'><strong>📌 8.1 Visão geral</strong></font>
#
# <font size="2" color='#66666'>
#
# >- Os critérios de sucesso definem como será avaliado se o projeto **Spotify Global Music Intelligence** atingiu seus objetivos analíticos, técnicos, executivos e de portfólio.
#
# >- Nesta fase, o sucesso não será medido pela construção de um modelo preditivo final, mas pela capacidade de estruturar uma análise exploratória robusta,
#     - orientada a negócio, tecnicamente confiável e preparada para evolução futura.
#
# >- A definição prévia desses critérios ajuda a manter o projeto focado, evita análises dispersas e cria uma base clara para validar se a entrega gerou valor.
#
# </font></div>

# %% [markdown]
# <div style="background-color:#f3f2ee">
#
# <font size="3" color='#CC403E'><strong>📌 8.2 Critério principal de sucesso</strong></font>
#
# <font size="2" color='#66666'>
#
# >- O projeto será considerado bem-sucedido nesta fase se conseguir transformar os dados brutos do Spotify em uma análise exploratória estruturada,
#     - capaz de responder perguntas relevantes sobre popularidade musical, evolução temporal, comportamento de artistas, qualidade dos dados e oportunidades futuras de modelagem.
#
# >- De forma resumida:
#     - ***O sucesso do projeto será alcançado se a EDA conseguir gerar entendimento confiável, acionável e bem documentado sobre padrões de popularidade musical no Spotify,***
#         - ***preparando uma base analítica sólida para futuras etapas de machine learning e produto de dados.***
#
# </font></div>

# %% [markdown]
# <div style="background-color:#f3f2ee">
#
# <font size="3" color='#CC403E'><strong>📌 8.3 Critérios de sucesso de negócio</strong></font>
#
# <font size="2" color='#66666'>
#
# | Critério | Descrição | Evidência esperada |
# |---|---|---|
# | Clareza da dor de negócio | O problema precisa estar bem definido e conectado ao mercado musical | Seção de problema de negócio documentada |
# | Relevância das perguntas analíticas | As perguntas devem apoiar decisões reais de marketing, curadoria, produto e investimento | Matriz de perguntas analíticas |
# | Conexão com stakeholders | A análise deve considerar diferentes públicos interessados | Mapeamento de stakeholders e necessidades |
# | Geração de insights acionáveis | A EDA deve produzir interpretações úteis, não apenas gráficos | Síntese executiva ao final da EDA |
# | Apoio à tomada de decisão | Os resultados devem indicar possíveis caminhos de ação | Recomendações finais documentadas |
#
# </font></div>

# %% [markdown]
# <div style="background-color:#f3f2ee">
#
# <font size="3" color='#CC403E'><strong>📌 8.4 Critérios de sucesso técnico</strong></font>
#
# <font size="2" color='#66666'>
#
# | Critério | Descrição | Evidência esperada |
# |---|---|---|
# | Estrutura de projeto organizada | O projeto deve seguir estrutura profissional de diretórios | Pastas `data`, `notebooks`, `src` e `reports` criadas |
# | Ambiente reprodutível | Dependências devem estar documentadas e instaláveis | Arquivo `pyproject.toml` e ambiente `uv` |
# | Código reutilizável | Funções auxiliares devem ser separadas em módulos | Pacote `src/spotify_intelligence` |
# | Camadas de dados definidas | Dados devem seguir fluxo Raw, Bronze, Silver e Gold | Diretórios de dados em camadas |
# | Notebooks organizados | Cada notebook deve ter papel claro no ciclo analítico | Sequência de notebooks 00 a 04 |
# | Exportabilidade | A análise deve poder ser exportada para HTML futuramente | Pasta `reports/html` e notebooks documentados |
#
# </font></div>

# %% [markdown]
# <div style="background-color:#f3f2ee">
#
# <font size="3" color='#CC403E'><strong>📌 8.5 Critérios de sucesso de qualidade dos dados</strong></font>
#
# <font size="2" color='#66666'>
#
# | Critério | Descrição | Evidência esperada |
# |---|---|---|
# | Leitura correta dos arquivos | Os CSVs devem ser carregados sem erros críticos | DataFrames carregados no Notebook 01 |
# | Diagnóstico de estrutura | Linhas, colunas e tipos devem ser conhecidos | Relatório de estrutura dos datasets |
# | Avaliação de nulos | Colunas com valores ausentes devem ser identificadas | Tabela de nulos e percentual por coluna |
# | Avaliação de duplicidades | Registros duplicados devem ser mensurados | Relatório de duplicidade |
# | Padronização de colunas | Nomes e tipos devem ser ajustados quando necessário | Dataset tratado na camada Silver |
# | Cobertura temporal validada | O período 2009–2025 deve ser analisado criticamente | Distribuição por ano ou período |
#
# </font></div>

# %% [markdown]
# <div style="background-color:#f3f2ee">
#
# <font size="3" color='#CC403E'><strong>📌 8.6 Critérios de sucesso analítico</strong></font>
#
# <font size="2" color='#66666'>
#
# | Critério | Descrição | Evidência esperada |
# |---|---|---|
# | Distribuição de popularidade analisada | Entender como a popularidade se comporta no dataset | Histogramas, estatísticas e interpretação |
# | Artistas relevantes identificados | Mapear artistas com maior presença e popularidade | Rankings por artista |
# | Faixas de destaque identificadas | Listar músicas mais populares do dataset | Ranking de faixas |
# | Evolução temporal analisada | Avaliar mudanças por ano ou período | Gráficos temporais |
# | Atributos musicais explorados | Investigar variáveis como energia, dança, valência ou duração, caso disponíveis | Análises univariadas e bivariadas |
# | Correlações avaliadas | Medir relações entre variáveis numéricas | Matriz de correlação |
# | Outliers identificados | Detectar músicas ou artistas com comportamento atípico | Boxplots e análises de extremos |
# | Hipóteses avaliadas | Confirmar, refutar ou classificar hipóteses como inconclusivas | Matriz de validação de hipóteses |
#
# </font></div>

# %% [markdown]
# <div style="background-color:#f3f2ee">
#
# <font size="3" color='#CC403E'><strong>📌 8.7 Critérios de sucesso executivo</strong></font>
#
# <font size="2" color='#66666'>
#
# | Critério | Descrição | Evidência esperada |
# |---|---|---|
# | Storytelling claro | A análise deve contar uma história compreensível | Notebook com narrativa progressiva |
# | Linguagem acessível | Os resultados devem ser entendidos por públicos técnicos e não técnicos | Explicações executivas após gráficos |
# | Recomendações objetivas | A entrega deve indicar próximos passos claros | Seção de recomendações |
# | Limitações reconhecidas | A análise deve explicitar riscos e restrições | Seção de limitações |
# | Próximos passos definidos | A EDA deve apontar caminho para modelagem ou produto | Roadmap futuro documentado |
#
# </font></div>

# %% [markdown]
# <div style="background-color:#f3f2ee">
#
# <font size="3" color='#CC403E'><strong>📌 8.8 Critérios de sucesso para portfólio</strong></font>
#
# <font size="2" color='#66666'>
#
# | Critério | Descrição | Evidência esperada |
# |---|---|---|
# | Projeto com narrativa profissional | O projeto deve parecer uma entrega de mercado | README e notebooks bem documentados |
# | Demonstração de raciocínio analítico | O trabalho deve mostrar pensamento estruturado | Problema, perguntas, hipóteses e critérios claros |
# | Demonstração técnica | O projeto deve evidenciar domínio de Python, Pandas, EDA e organização | Código limpo e módulos auxiliares |
# | Demonstração executiva | O projeto deve traduzir análise em decisão | Insights e recomendações |
# | Reutilização futura | A estrutura deve servir como template para novos projetos | Framework replicável de EDA |
# | Potencial de publicação | O projeto deve poder virar página HTML, post ou apresentação | Relatórios e exportações planejadas |
#
# </font></div>

# %% [markdown]
# <div style="background-color:#f3f2ee">
#
# <font size="3" color='#CC403E'><strong>📌 8.9 Critérios de prontidão para modelagem futura</strong></font>
#
# <font size="2" color='#66666'>
#
# >- Embora a modelagem não seja o objetivo desta fase, a EDA deve indicar se o projeto pode evoluir para machine learning.
#
# | Critério | Descrição | Evidência esperada |
# |---|---|---|
# | Target potencial identificado | A variável de popularidade pode ser analisada como alvo | Discussão sobre regressão ou classificação |
# | Features candidatas mapeadas | Variáveis relevantes devem ser identificadas | Lista de variáveis úteis |
# | Riscos de modelagem identificados | Possíveis problemas devem ser documentados | Discussão sobre vazamento, viés e qualidade |
# | Classes de popularidade avaliadas | Possibilidade de criar baixa, média e alta popularidade | Análise por percentis |
# | Baseline futuro proposto | Indicação de modelo simples inicial | Sugestão de regressão ou classificação baseline |
# | Viabilidade técnica avaliada | A base deve ser considerada adequada ou não para ML | Diagnóstico final da fase EDA |
#
# </font></div>

# %% [markdown]
# <div style="background-color:#f3f2ee">
#
# <font size="3" color='#CC403E'><strong>📌 8.10 Matriz resumida de sucesso</strong></font>
#
# <font size="2" color='#66666'>
#
# | Dimensão | Pergunta de validação | Status esperado ao final da fase |
# |---|---|---|
# | Negócio | O problema foi bem definido? | Sim |
# | Dados | A estrutura dos datasets foi compreendida? | Sim |
# | Qualidade | Os principais problemas foram identificados? | Sim |
# | EDA | As perguntas principais foram exploradas? | Sim |
# | Hipóteses | As hipóteses foram avaliadas com evidências? | Sim ou parcialmente |
# | Insights | Os achados foram traduzidos para negócio? | Sim |
# | Portfólio | O projeto comunica valor profissional? | Sim |
# | Futuro ML | Há caminho claro para modelagem? | Sim, se os dados permitirem |
#
# </font></div>

# %% [markdown]
# <div style="background-color:#f3f2ee">
#
# <font size="3" color='#CC403E'><strong>📌 8.11 Critérios mínimos para fechamento do Cap01</strong></font>
#
# <font size="2" color='#66666'>
#
# - Para considerar a etapa de EDA do Cap01 concluída, os seguintes itens mínimos deverão estar prontos:
#     - *estrutura do projeto criada;*
#     - *ambiente Python configurado;*
#     - *Notebook 00 concluído;*
#     - *datasets carregados no Notebook 01;*
#     - *diagnóstico inicial dos dados realizado;*
#     - *análise de qualidade executada;*
#     - *base tratada salva em camada Silver;*
#     - *EDA principal executada no Notebook 03;*
#     - *principais insights consolidados;*
#     - *recomendações documentadas;*
#     - *próximos passos para modelagem definidos;*
#     - *README atualizado;*
#     - *exportação HTML planejada ou realizada.*
#
# </font></div>

# %% [markdown]
# <div style="background-color:#f3f2ee">
#
# <font size="3" color='#CC403E'><strong>📌 8.12 Resultado esperado desta etapa</strong></font>
#
# <font size="2" color='#66666'>
#
# >- Ao final desta etapa, espera-se ter uma definição clara de sucesso para o projeto, cobrindo as dimensões de negócio, técnica,
#     - qualidade dos dados, análise exploratória, comunicação executiva, portfólio e evolução futura.
#
# >- Esses critérios serão utilizados como referência ao longo dos próximos notebooks para avaliar se a entrega está avançando de forma consistente, profissional e orientada a valor.
#
# >- Com isso, o projeto passa a ter não apenas perguntas e hipóteses, mas também uma forma objetiva de medir se a análise gerou o resultado esperado.
#
# ---
# </font></div>

# %% [markdown]
# <div style="background-color:#f3f2ee">
#
# <font size="4" color='#CC403E'><strong>📌 9. Escopo, não escopo e premissas do projeto</strong></font>
#
# <font size="2" color='#66666'></font></div>

# %% [markdown]
# <div style="background-color:#f3f2ee">
#
# <font size="3" color='#CC403E'><strong>📌 9.1 Visão geral</strong></font>
#
# <font size="2" color='#66666'>
#
# >- Definir o escopo de um projeto analítico é essencial para evitar dispersão, controlar expectativas e garantir que a entrega esteja alinhada aos objetivos definidos.
#
# >- No projeto **Spotify Global Music Intelligence**, o escopo inicial está concentrado na construção de uma análise exploratória profissional,
#     - orientada a negócio, qualidade dos dados, identificação de padrões e preparação para futuras etapas de modelagem.
#
# >- Esta etapa não tem como objetivo entregar imediatamente um modelo em produção, mas sim criar a base analítica necessária para que essa evolução seja tecnicamente viável e estrategicamente justificável.
#
# </font></div>

# %% [markdown]
# <div style="background-color:#f3f2ee">
#
# <font size="3" color='#CC403E'><strong>📌 9.2 Escopo principal da fase atual</strong></font>
#
# <font size="2" color='#66666'>
#
# > - A fase atual do projeto contempla as etapas de entendimento de negócio, entendimento dos dados, preparação inicial e análise exploratória.
#
# | Área | Dentro do escopo |
# |---|---|
# | Business Understanding | Definir contexto, problema, objetivos, stakeholders, perguntas, hipóteses e critérios de sucesso |
# | Data Understanding | Compreender estrutura dos arquivos, colunas, tipos, granularidade e período coberto |
# | Data Quality | Avaliar nulos, duplicidades, cardinalidade, inconsistências e limitações |
# | Data Preparation | Padronizar colunas, ajustar tipos e preparar base analítica intermediária |
# | EDA | Explorar popularidade, artistas, faixas, evolução temporal, atributos musicais e relações entre variáveis |
# | Insights | Traduzir achados técnicos em interpretações executivas |
# | Portfólio | Documentar o projeto com narrativa profissional, notebooks e README |
# | Continuidade | Preparar caminho para modelagem, dashboard e produto de dados |
#
# </font></div>

# %% [markdown]
# <div style="background-color:#f3f2ee">
#
# <font size="3" color='#CC403E'><strong>📌 9.3 Escopo dos notebooks planejados</strong></font>
#
# <font size="2" color='#66666'>
#
# >- O projeto será organizado em notebooks sequenciais, cada um com uma função clara dentro do ciclo analítico.
#
# | Notebook | Papel no projeto | Escopo |
# |---|---|---|
# | Notebook 00 — Business Understanding | Definir o contrato analítico do projeto | Contexto, problema, objetivos, stakeholders, perguntas, hipóteses e critérios de sucesso |
# | Notebook 01 — Data Understanding | Avaliar os dados disponíveis | Leitura dos arquivos, estrutura, tipos, granularidade, colunas e primeiras observações |
# | Notebook 02 — Data Quality and Preparation | Preparar dados confiáveis para análise | Tratamento inicial, padronização, nulos, duplicidades, tipos e camada Silver |
# | Notebook 03 — Exploratory Data Analysis | Investigar padrões e relações | Popularidade, artistas, faixas, períodos, atributos musicais, correlações e outliers |
# | Notebook 04 — Executive Insights and Next Steps | Consolidar a entrega | Principais achados, recomendações, limitações e próximos passos |
#
# </font></div>

# %% [markdown]
# <div style="background-color:#f3f2ee">
#
# <font size="3" color='#CC403E'><strong>📌 9.4 Escopo de dados</strong></font>
#
# <font size="2" color='#66666'>
#
# >- Nesta fase, o projeto utilizará os arquivos disponibilizados no dataset **Spotify Global Music Dataset (2009–2025)**.
#
# | Arquivo | Uso previsto |
# |---|---|
# | `spotify_data_clean.csv` | Base com músicas modernas e artistas recentes |
# | `track_data_final.csv` | Base com músicas clássicas/populares de artistas entre 2009 e 2023 |
#
# > A análise irá verificar se esses arquivos podem ser integrados em uma base unificada ou se deverão ser analisados separadamente em alguns momentos.
#
# </font></div>

# %% [markdown]
# <div style="background-color:#f3f2ee">
#
# <font size="3" color='#CC403E'><strong>📌 9.5 Escopo analítico</strong></font>
#
# <font size="2" color='#66666'>
#
# - As análises exploratórias planejadas incluem:
#     - *distribuição geral da popularidade;*
#     - *ranking de músicas mais populares;*
#     - *ranking de artistas por popularidade média;*
#     - *quantidade de faixas por artista;*
#     - *concentração de popularidade;*
#     - *evolução temporal por ano ou período;*
#     - *comparação entre músicas antigas e recentes;*
#     - *análise de atributos musicais, caso disponíveis;*
#     - *investigação de correlações entre variáveis numéricas;*
#     - *identificação de outliers;*
#     - *preparação de insights executivos;*
#     - *avaliação da viabilidade de modelagem futura.*
#
# </font></div>

# %% [markdown]
# <div style="background-color:#f3f2ee">
#
# <font size="3" color='#CC403E'><strong>📌 9.6 Não escopo da fase atual</strong></font>
#
# <font size="2" color='#66666'>
#
# >- Para manter o projeto controlado e bem organizado, alguns itens não serão tratados nesta primeira fase.
#
# | Item fora do escopo | Motivo |
# |---|---|
# | Construção de modelo preditivo final | Será uma etapa posterior, após EDA e preparação dos dados |
# | Deploy de modelo em produção | Depende de validação prévia da viabilidade analítica |
# | API de recomendação musical | Exige arquitetura e escopo próprios |
# | Dashboard Streamlit final | Será considerado após a consolidação dos insights |
# | Integração direta com a API do Spotify | O projeto utilizará inicialmente os arquivos do Kaggle |
# | Inferência causal | A EDA identifica associações, não causalidade |
# | Análise regional de consumo | Depende de variáveis geográficas disponíveis |
# | Análise de usuários ou comportamento individual | O dataset está no nível de músicas, artistas e faixas |
# | Estratégia real de lançamento musical | O projeto simula contexto de negócio para fins analíticos e de portfólio |
# | Uso comercial dos resultados | A análise tem finalidade educacional, técnica e demonstrativa |
#
# </font></div>

# %% [markdown]
# <div style="background-color:#f3f2ee">
#
# <font size="3" color='#CC403E'><strong>📌 9.7 Premissas do projeto</strong></font>
#
# <font size="2" color='#66666'>
#
# >- Algumas premissas serão adotadas para conduzir a análise.
#
# | Premissa | Descrição |
# |---|---|
# | Fonte de dados | Os dados disponíveis serão tratados como base inicial confiável para fins educacionais |
# | Popularidade | A variável de popularidade será considerada um indicador relevante de desempenho musical |
# | Granularidade | A principal unidade de análise será a faixa musical |
# | Período | O projeto considerará o recorte temporal informado de 2009 a 2025 |
# | Integração | A união dos arquivos dependerá da compatibilidade de colunas e conceitos |
# | Qualidade | Problemas de nulos, duplicidades e tipos serão documentados antes de qualquer análise conclusiva |
# | Interpretação | Resultados serão tratados como evidências exploratórias, não como verdades causais |
# | Evolução | A EDA deverá preparar caminho para feature engineering e modelagem futura |
#
# </font></div>

# %% [markdown]
# <div style="background-color:#f3f2ee">
#
# <font size="3" color='#CC403E'><strong>📌 9.8 Restrições conhecidas</strong></font>
#
# <font size="2" color='#66666'>
#
# Antes da análise dos dados, algumas restrições já podem ser reconhecidas.
#
# | Restrição | Possível impacto |
# |---|---|
# | Dados coletados via API pública | Pode haver limitação de variáveis disponíveis |
# | Ausência de dados de usuários | Não será possível analisar comportamento individual de consumo |
# | Ausência de dados financeiros | Não será possível estimar receita ou retorno sobre investimento |
# | Possível viés de seleção | O dataset pode representar apenas faixas escolhidas ou populares |
# | Popularidade como métrica agregada | Pode não capturar todos os fatores de sucesso musical |
# | Ausência de contexto externo | Marketing, redes sociais, playlists e mídia podem não estar representados |
# | Diferenças entre arquivos | Pode haver necessidade de harmonização antes da integração |
# | Atualização temporal | Dados de 2025 podem representar um recorte específico e não o ano completo |
#
# </font></div>

# %% [markdown]
# <div style="background-color:#f3f2ee">
#
# <font size="3" color='#CC403E'><strong>📌 9.9 Riscos analíticos</strong></font>
#
# <font size="2" color='#66666'>
#
# >- Alguns riscos deverão ser monitorados ao longo do projeto.
#
# | Risco | Mitigação |
# |---|---|
# | Interpretar correlação como causalidade | Deixar claro que a EDA identifica associações |
# | Gerar rankings sem considerar volume de músicas | Usar métricas complementares como contagem e média |
# | Comparar períodos com volumes muito diferentes | Normalizar ou contextualizar análises temporais |
# | Unificar bases incompatíveis | Validar colunas, tipos e granularidade antes da junção |
# | Usar variável de popularidade sem entender sua distribuição | Analisar estatísticas, percentis e outliers |
# | Tirar conclusões com dados incompletos | Documentar limitações e lacunas |
# | Excesso de gráficos sem narrativa | Conectar cada visualização a uma pergunta analítica |
#
# </font></div>

# %% [markdown]
# <div style="background-color:#f3f2ee">
#
# <font size="3" color='#CC403E'><strong>📌 9.10 Decisões metodológicas iniciais</strong></font>
#
# <font size="2" color='#66666'>
#
# Para manter o projeto consistente, serão adotadas algumas decisões metodológicas.
#
# | Decisão | Justificativa |
# |---|---|
# | Utilizar CRISP-DM+ como estrutura orientadora | Garante organização entre negócio, dados, análise e evolução futura |
# | Separar notebooks por fase | Melhora legibilidade, manutenção e narrativa do projeto |
# | Usar camadas Raw, Bronze, Silver e Gold | Aproxima o projeto de uma arquitetura real de dados |
# | Documentar cada etapa em Markdown | Facilita comunicação técnica e executiva |
# | Criar funções reutilizáveis em `src` | Evita repetição de código e melhora profissionalismo |
# | Salvar bases tratadas em Parquet | Melhora performance e padronização para análises futuras |
# | Manter foco inicial em EDA | Evita antecipar modelagem antes da compreensão dos dados |
#
# </font></div>

# %% [markdown]
# <div style="background-color:#f3f2ee">
#
# <font size="3" color='#CC403E'><strong>📌 9.11 Entregáveis dentro do escopo</strong></font>
#
# <font size="2" color='#66666'>
#
# >- Ao final da fase atual, espera-se produzir os seguintes entregáveis:
#
# | Entregável | Descrição |
# |---|---|
# | Notebook 00 | Entendimento de negócio completo |
# | Notebook 01 | Diagnóstico inicial dos dados |
# | Notebook 02 | Qualidade e preparação dos dados |
# | Notebook 03 | Análise exploratória principal |
# | Notebook 04 | Insights executivos e próximos passos |
# | Dataset Bronze | Base bruta unificada ou organizada |
# | Dataset Silver | Base limpa e preparada para EDA |
# | Tabelas Gold | Sumarizações por artista, faixa e período |
# | README | Documentação executiva do projeto |
# | Relatório HTML | Exportação futura para portfólio |
# | Recomendações | Próximos passos para modelagem e produto |
#
# </font></div>

# %% [markdown]
# <div style="background-color:#f3f2ee">
#
# <font size="3" color='#CC403E'><strong>📌 9.12 Resultado esperado desta etapa</strong></font>
#
# <font size="2" color='#66666'>
#
# >- Ao final desta etapa, espera-se ter uma definição clara sobre o que será entregue, o que ficará fora da fase atual, quais premissas orientam o projeto e quais riscos precisam ser considerados.
#
# >- Essa definição ajudará a manter o projeto organizado, profissional e alinhado ao objetivo principal: construir uma EDA robusta, orientada a negócio e preparada para evolução futura.
#
# >- Com isso, o projeto passa a ter limites bem definidos, evitando dispersão e garantindo que as próximas etapas sejam executadas com foco, rastreabilidade e clareza.
#
# ---
# </font></div>

# %% [markdown]
# <div style="background-color:#f3f2ee">
#
# <font size="4" color='#CC403E'><strong>📌 10. Roadmap CRISP-DM+ do projeto</strong></font>
#
# <font size="2" color='#66666'></font></div>

# %% [markdown]
# <div style="background-color:#f3f2ee">
#
# <font size="3" color='#CC403E'><strong>📌 10.1 Visão geral</strong></font>
#
# <font size="2" color='#66666'>
#
# >- O projeto **Spotify Global Music Intelligence** será conduzido com base no framework **CRISP-DM+**, uma extensão prática do CRISP-DM tradicional
#     - adaptada para projetos modernos de dados, portfólio, engenharia analítica e preparação para produção.
#
# >- A proposta é organizar o projeto em fases progressivas, garantindo que cada etapa tenha objetivo claro, entregáveis definidos e conexão com a geração de valor para o negócio.
#
# >- No contexto deste projeto, o CRISP-DM+ será usado para conectar:
#     - entendimento do domínio musical;
#     - entendimento do problema de negócio;
#     - avaliação dos dados disponíveis;
#     - preparação e organização em camadas;
#     - análise exploratória;
#     - geração de insights;
#     - preparação para modelagem;
#     - possível evolução para produto de dados;
#     - monitoramento futuro.
#
# >- Essa abordagem está alinhada à lógica de uma EDA profissional, que parte do entendimento do problema, passa pelo entendimento dos dados,
#     - formulação de hipóteses, preparação, visualização, insights e recomendações.
#
# </font></div>

# %% [markdown]
# <div style="background-color:#f3f2ee">
#
# <font size="3" color='#CC403E'><strong>📌 10.2 Roadmap geral do CRISP-DM+</strong></font>
#
# <font size="2" color='#66666'>
#
# | Fase | Nome da fase | Objetivo no projeto |
# |---|---|---|
# | 0 | Domain Understanding | Compreender o domínio musical, streaming, popularidade e dinâmica de mercado |
# | 1 | Business Understanding | Definir problema, objetivos, stakeholders, perguntas, hipóteses e critérios de sucesso |
# | 2 | Data Understanding | Entender os arquivos, colunas, tipos, granularidade, períodos e limitações |
# | 3 | Data Preparation | Limpar, padronizar, integrar e preparar os dados em camadas analíticas |
# | 4 | Exploratory Data Analysis | Investigar padrões de popularidade, artistas, faixas, períodos e atributos musicais |
# | 5 | Modeling Readiness | Avaliar viabilidade para modelos de popularidade, classificação ou segmentação |
# | 6 | Evaluation & Business Interpretation | Consolidar achados, validar hipóteses e traduzir resultados em recomendações |
# | 7 | Deployment & Monitoring Vision | Planejar evolução futura para dashboard, API, modelo ou produto de dados |
#
# </font></div>

# %% [markdown]
# <div style="background-color:#f3f2ee">
#
# <font size="3" color='#CC403E'><strong>📌 10.3 Fase 0 — Domain Understanding</strong></font>
#
# <font size="2" color='#66666'>
#
# >- **Objetivo**
#     - Compreender o contexto do mercado musical e da indústria de streaming antes de analisar os dados.
#
# >- **Aplicação no projeto**
#     - Nesta fase, o projeto busca entender conceitos como:
#         - popularidade musical;
#         - artistas;
#         - faixas;
#         - álbuns;
#         - streaming;
#         - playlists;
#         - atributos musicais;
#         - comportamento temporal;
#         - dinâmica de hits;
#         - catálogo musical;
#         - tendências de consumo.
#
# >- **Resultado esperado**
#     - Criar uma base conceitual mínima para interpretar os dados corretamente e evitar análises desconectadas do domínio.
#
# </font></div>

# %% [markdown]
# <div style="background-color:#f3f2ee">
#
# <font size="3" color='#CC403E'><strong>📌 10.4 Fase 1 — Business Understanding</strong></font>
#
# <font size="2" color='#66666'>
#
# >- **Objetivo**
#     - Definir o problema de negócio, os objetivos da análise e as perguntas que orientarão o projeto.
#
# >- **Aplicação no projeto**
#     - Esta fase está concentrada no **Notebook 00 — Business Understanding**.
#     - Ela contempla:
#         - abertura executiva do projeto;
#         - contexto de mercado;
#         - dor de negócio;
#         - objetivos;
#         - stakeholders;
#         - perguntas analíticas;
#         - hipóteses;
#         - critérios de sucesso;
#         - escopo;
#         - premissas;
#         - roadmap analítico.
#
# >- **Resultado esperado**
#     - Um contrato analítico claro, demonstrando por que o projeto existe, quais decisões pretende apoiar e como a EDA será conduzida.
#
# </font></div>

# %% [markdown]
# <div style="background-color:#f3f2ee">
#
# <font size="3" color='#CC403E'><strong>📌 10.5 Fase 2 — Data Understanding</strong></font>
#
# <font size="2" color='#66666'>
#
# >- **Objetivo**
#     - Compreender os dados disponíveis antes de qualquer tratamento ou análise avançada.
#
# >- **Aplicação no projeto**
#     - Esta fase será executada no **Notebook 01 — Data Understanding**.
#     - As principais atividades serão:
#         - carregar os arquivos CSV;
#         - verificar dimensões dos datasets;
#         - listar colunas disponíveis;
#         - comparar estrutura dos arquivos;
#         - identificar tipos de dados;
#         - avaliar granularidade;
#         - verificar período coberto;
#         - analisar primeiras amostras;
#         - identificar chaves potenciais;
#         - avaliar possibilidade de integração.
#
# >- **Resultado esperado**
#     - Diagnóstico inicial dos dados, indicando se os arquivos podem ser integrados, quais variáveis existem e quais cuidados serão necessários.
#
# </font></div>

# %% [markdown]
# <div style="background-color:#f3f2ee">
#
# <font size="3" color='#CC403E'><strong>📌 10.6 Fase 3 — Data Preparation</strong></font>
#
# <font size="2" color='#66666'>
#
# - **Objetivo**
#     - Preparar os dados para uma análise exploratória confiável.
#
# - **Aplicação no projeto**
#     - Esta fase será executada no **Notebook 02 — Data Quality and Preparation**.
#     - As principais atividades serão:
#         - padronizar nomes de colunas;
#         - ajustar tipos de dados;
#         - tratar datas;
#         - avaliar valores nulos;
#         - identificar duplicidades;
#         - analisar cardinalidade;
#         - verificar inconsistências;
#         - harmonizar arquivos;
#         - criar colunas auxiliares;
#         - salvar base tratada em Parquet;
#         - estruturar camadas Bronze, Silver e Gold.
#
# - **Resultado esperado**
#     - Uma base Silver limpa e confiável para a EDA, além de tabelas Gold sumarizadas por artista, faixa e período.
#
# </font></div>

# %% [markdown]
# <div style="background-color:#f3f2ee">
#
# <font size="3" color='#CC403E'><strong>📌 10.7 Fase 4 — Exploratory Data Analysis</strong></font>
#
# <font size="2" color='#66666'>
#
# - **Objetivo**
#     - Investigar padrões, relações, distribuições e tendências presentes nos dados.
#
# - **Aplicação no projeto**
#     - Esta fase será executada no **Notebook 03 — Exploratory Data Analysis**.
#     - As análises planejadas incluem:
#         - distribuição da popularidade;
#         - rankings de faixas;
#         - rankings de artistas;
#         - análise de concentração;
#         - evolução temporal;
#         - comparação entre períodos;
#         - análise de atributos musicais;
#         - correlação entre variáveis;
#         - identificação de outliers;
#         - avaliação das hipóteses;
#         - preparação de insights executivos.
#
# - **Resultado esperado**
#     - Um conjunto robusto de evidências exploratórias que ajude a explicar padrões de popularidade musical no dataset.
#
# </font></div>

# %% [markdown]
# <div style="background-color:#f3f2ee">
#
# <font size="3" color='#CC403E'><strong>📌 10.8 Fase 5 — Modeling Readiness</strong></font>
#
# <font size="2" color='#66666'>
#
# >- **Objetivo**
#     - Avaliar se os dados estão prontos para uma futura etapa de modelagem.
#
# >- **Aplicação no projeto**
#     - Nesta fase, ainda não será criado um modelo final. O foco será avaliar possibilidades como:
#         - previsão de popularidade;
#         - classificação de potencial de hit;
#         - segmentação de músicas;
#         - agrupamento de artistas;
#         - criação de features;
#         - definição de target;
#         - identificação de riscos de vazamento;
#         - escolha de baseline futuro.
#
# >- **Possíveis abordagens futuras**
#
# | Abordagem | Descrição |
# |---|---|
# | Regressão | Prever popularidade como variável numérica |
# | Classificação | Classificar músicas em baixa, média ou alta popularidade |
# | Clusterização | Agrupar músicas por atributos musicais |
# | Ranking | Priorizar faixas com maior potencial analítico |
# | Recomendação | Explorar similaridade entre músicas ou artistas |
#
# >- **Resultado esperado**
#     - Definir se o projeto tem maturidade suficiente para avançar para machine learning e quais seriam os caminhos mais adequados.
#
# </font></div>

# %% [markdown]
# <div style="background-color:#f3f2ee">
#
# <font size="3" color='#CC403E'><strong>📌 10.9 Fase 6 — Evaluation & Business Interpretation</strong></font>
#
# <font size="2" color='#66666'>
#
# >- **Objetivo**
#     - Consolidar os resultados da análise e traduzir os achados técnicos em interpretação executiva.
#
# >- **Aplicação no projeto**
#     - Esta fase será trabalhada principalmente no **Notebook 04 — Executive Insights and Next Steps**.
#     - As atividades incluem:
#         - consolidar principais achados;
#         - validar hipóteses;
#         - destacar limitações;
#         - identificar recomendações;
#         - conectar resultados aos stakeholders;
#         - documentar aprendizados;
#         - propor próximos passos;
#         - preparar narrativa para portfólio.
#
# >- **Resultado esperado**
#     - Uma conclusão executiva clara, com recomendações e direcionamentos para evolução do projeto.
#
# </font></div>

# %% [markdown]
# <div style="background-color:#f3f2ee">
#
# <font size="3" color='#CC403E'><strong>📌 10.10 Fase 7 — Deployment & Monitoring Vision</strong></font>
#
# <font size="2" color='#66666'>
#
# >- **Objetivo**
#     - Planejar como o projeto poderia evoluir para uma solução analítica ou produto de dados.
#
# >- **Aplicação futura**
#     - Embora o deploy não esteja dentro do escopo inicial, o projeto será desenhado para permitir evolução futura para:
#         - dashboard em Streamlit;
#         - relatório HTML interativo;
#         - API de scoring de popularidade;
#         - modelo batch para ranking de faixas;
#         - monitoramento de mudanças de popularidade;
#         - acompanhamento de drift temporal;
#         - integração com pipeline de dados;
#         - publicação no GitHub Pages.
#
# >- **Resultado esperado**
#     - Uma visão clara de continuidade, mostrando que a EDA é a fundação para produtos analíticos mais avançados.
#
# </font></div>

# %% [markdown]
# <div style="background-color:#f3f2ee">
#
# <font size="3" color='#CC403E'><strong>📌 10.11 Relação entre fases e notebooks</strong></font>
#
# <font size="2" color='#66666'>
#
# | Fase CRISP-DM+ | Notebook relacionado | Entregável |
# |---|---|---|
# | Domain Understanding | Notebook 00 | Contexto de domínio e motivação |
# | Business Understanding | Notebook 00 | Problema, objetivos, stakeholders, perguntas e hipóteses |
# | Data Understanding | Notebook 01 | Diagnóstico inicial dos dados |
# | Data Preparation | Notebook 02 | Dados tratados e camadas Bronze/Silver/Gold |
# | Exploratory Data Analysis | Notebook 03 | Análises, gráficos, padrões e hipóteses avaliadas |
# | Evaluation & Interpretation | Notebook 04 | Insights executivos e recomendações |
# | Deployment Vision | Notebook 04 / fases futuras | Plano para dashboard, modelo ou produto de dados |
#
# </font></div>

# %% [markdown]
# <div style="background-color:#f3f2ee">
#
# <font size="3" color='#CC403E'><strong>📌 10.12 Roadmap operacional do projeto</strong></font>
#
# <font size="2" color='#66666'>
#
# | Etapa | Atividade | Status inicial |
# |---|---|---|
# | 1 | Criar estrutura do projeto | Planejado/concluído |
# | 2 | Configurar ambiente Python | Planejado/concluído |
# | 3 | Criar Notebook 00 | Em execução |
# | 4 | Finalizar Business Understanding | Em andamento |
# | 5 | Carregar datasets no Notebook 01 | Pendente |
# | 6 | Diagnosticar estrutura dos dados | Pendente |
# | 7 | Avaliar qualidade dos dados | Pendente |
# | 8 | Preparar camada Silver | Pendente |
# | 9 | Executar EDA principal | Pendente |
# | 10 | Consolidar insights executivos | Pendente |
# | 11 | Atualizar README | Pendente |
# | 12 | Exportar HTML para portfólio | Pendente |
# | 13 | Planejar modelagem futura | Pendente |
#
# </font></div>

# %% [markdown]
# <div style="background-color:#f3f2ee">
#
# <font size="3" color='#CC403E'><strong>📌 10.13 Entregáveis por fase</strong></font>
#
# <font size="2" color='#66666'>
#
# | Fase | Entregável principal |
# |---|---|
# | Business Understanding | Notebook 00 completo |
# | Data Understanding | Relatório inicial de estrutura dos dados |
# | Data Preparation | Base Silver em Parquet |
# | EDA | Notebook com gráficos, tabelas e interpretações |
# | Executive Insights | Síntese executiva e recomendações |
# | Portfolio Packaging | README, HTML e narrativa para divulgação |
# | Future Modeling | Plano de modelagem e critérios de viabilidade |
#
# </font></div>

# %% [markdown]
# <div style="background-color:#f3f2ee">
#
# <font size="3" color='#CC403E'><strong>📌 10.14 Resultado esperado desta etapa</strong></font>
#
# <font size="2" color='#66666'>
#
# >- Ao final desta etapa, espera-se ter um roadmap completo para orientar a execução do projeto.
#
# >- Esse roadmap conecta metodologia, notebooks, entregáveis e evolução futura, garantindo que o projeto seja conduzido com clareza, rastreabilidade e maturidade profissional.
#
# >- Com isso, o **Spotify Global Music Intelligence** passa a ter uma rota analítica completa, partindo do entendimento do negócio até
#     - a preparação para futuras soluções de machine learning, produto de dados e portfólio.
#
# ---
# </font></div>

# %% [markdown]
# <div style="background-color:#f3f2ee">
#
# <font size="4" color='#CC403E'><strong>📌 11. Próximos passos e encerramento do Notebook 00</strong></font>
#
# <font size="2" color='#66666'></font></div>

# %% [markdown]
# <div style="background-color:#f3f2ee">
#
# <font size="3" color='#CC403E'><strong>📌 11.1 Visão geral</strong></font>
#
# <font size="2" color='#66666'>
#
# >- Este notebook teve como objetivo estruturar a fase de **Business Understanding** do projeto **Spotify Global Music Intelligence**.
#
# >- Antes de iniciar qualquer carregamento de dados, tratamento de arquivos ou geração de gráficos, o projeto foi contextualizado
#     - como uma entrega analítica orientada a negócio, com problema definido, stakeholders mapeados, perguntas analíticas formuladas,
#     - hipóteses estruturadas, critérios de sucesso estabelecidos e roadmap metodológico definido.
#
# >- Essa abordagem reforça que uma EDA profissional deve começar pela compreensão do problema, e não pela visualização imediata dos dados.
#
# </font></div>

# %% [markdown]
# <div style="background-color:#f3f2ee">
#
# <font size="3" color='#CC403E'><strong>📌 11.2 O que foi construído neste notebook</strong></font>
#
# <font size="2" color='#66666'>
#
# >- Ao longo deste notebook, foram definidos os principais elementos estratégicos do projeto.
#
# | Etapa | Entrega realizada |
# |---|---|
# | Abertura executiva | Apresentação do projeto e de sua proposta analítica |
# | Contexto de mercado | Descrição do cenário de streaming, música e inteligência musical |
# | Dor de negócio | Formulação do problema central a ser investigado |
# | Objetivos do projeto | Definição dos objetivos técnicos, analíticos, executivos e de portfólio |
# | Stakeholders | Mapeamento dos públicos interessados e suas necessidades |
# | Perguntas analíticas | Construção da matriz de perguntas que guiará a investigação |
# | Hipóteses | Formulação de suposições testáveis para a EDA |
# | Critérios de sucesso | Definição de como avaliar se a entrega gerou valor |
# | Escopo e premissas | Delimitação do que será feito, do que ficará fora e das restrições conhecidas |
# | Roadmap CRISP-DM+ | Organização das fases, notebooks e entregáveis do projeto |
#
# </font></div>

# %% [markdown]
# <div style="background-color:#f3f2ee">
#
# <font size="3" color='#CC403E'><strong>📌 11.3 Principais decisões tomadas</strong></font>
#
# <font size="2" color='#66666'>
#
# >- Durante a fase de Business Understanding, algumas decisões metodológicas importantes foram estabelecidas.
#
# | Decisão | Justificativa |
# |---|---|
# | Tratar o projeto como uma simulação real de consultoria | Aumenta o valor profissional e executivo da entrega |
# | Usar CRISP-DM+ como estrutura orientadora | Garante rastreabilidade entre negócio, dados, EDA e evolução futura |
# | Separar o projeto em notebooks sequenciais | Melhora organização, leitura e manutenção |
# | Trabalhar com camadas Raw, Bronze, Silver e Gold | Aproxima o projeto de práticas reais de engenharia analítica |
# | Priorizar EDA antes de modelagem | Evita construir modelos antes de entender qualidade, estrutura e padrões dos dados |
# | Documentar perguntas e hipóteses antes da análise | Reduz exploração dispersa e fortalece o storytelling analítico |
# | Considerar a popularidade como eixo central do projeto | Mantém foco em uma métrica relevante para negócio e modelagem futura |
#
# </font></div>

# %% [markdown]
# <div style="background-color:#f3f2ee">
#
# <font size="3" color='#CC403E'><strong>📌 11.4 Estado atual do projeto</strong></font>
#
# <font size="2" color='#66666'>
#
# >- Neste ponto, o projeto encontra-se na seguinte situação:
#
# | Dimensão | Status |
# |---|---|
# | Estrutura de diretórios | Preparada |
# | Ambiente Python | Preparado |
# | Notebook 00 | Em fase de conclusão |
# | Contexto de negócio | Definido |
# | Problema analítico | Definido |
# | Perguntas analíticas | Definidas |
# | Hipóteses | Definidas |
# | Critérios de sucesso | Definidos |
# | Escopo | Definido |
# | Roadmap | Definido |
# | Dados carregados | Próxima etapa |
# | EDA executada | Etapa futura |
#
# </font></div>

# %% [markdown]
# <div style="background-color:#f3f2ee">
#
# <font size="3" color='#CC403E'><strong>📌 11.5 Próximo notebook</strong></font>
#
# <font size="2" color='#66666'>
#
# >- A próxima etapa será o **Notebook 01 — Data Understanding**.
#
# > - Esse notebook terá como objetivo compreender os dados disponíveis antes de qualquer tratamento ou análise avançada.
#     - As principais atividades previstas são:
#         1. importar bibliotecas;
#         2. configurar caminhos do projeto;
#         3. localizar os arquivos na camada `data/00_raw`;
#         4. carregar os arquivos CSV;
#         5. inspecionar dimensões dos datasets;
#         6. visualizar primeiras amostras;
#         7. listar colunas disponíveis;
#         8. comparar estruturas dos arquivos;
#         9. avaliar tipos de dados;
#         10. identificar possíveis chaves de integração;
#         11. verificar cobertura temporal;
#         12. registrar primeiras observações sobre qualidade e viabilidade analítica.
#
# </font></div>

# %% [markdown]
# <div style="background-color:#f3f2ee">
#
# <font size="3" color='#CC403E'><strong>📌 11.6 Perguntas que orientarão o Notebook 01</strong></font>
#
# <font size="2" color='#66666'>
#
# >- O Notebook 01 será guiado principalmente pelas perguntas de estrutura e qualidade dos dados.
#
# | Código | Pergunta |
# |---|---|
# | QD01 | Quantas linhas e colunas existem em cada arquivo do dataset? |
# | QD02 | Os arquivos possuem a mesma estrutura de colunas? |
# | QD03 | Existem colunas com nomes diferentes, mas significado semelhante? |
# | QD04 | Quais colunas possuem valores ausentes? |
# | QD05 | Existem registros duplicados? |
# | QD06 | As variáveis possuem tipos de dados adequados? |
# | QD07 | Existem valores extremos ou inconsistentes? |
# | QD08 | O período 2009–2025 está corretamente representado? |
#
# </font></div>

# %% [markdown]
# <div style="background-color:#f3f2ee">
#
# <font size="3" color='#CC403E'><strong>📌 11.7 Entregável esperado do Notebook 01</strong></font>
#
# <font size="2" color='#66666'>
#
# > - Ao final do próximo notebook, espera-se produzir um diagnóstico inicial dos dados contendo:
#     - quantidade de registros por arquivo;
#     - quantidade de colunas por arquivo;
#     - comparação entre estruturas;
#     - identificação de variáveis comuns;
#     - identificação de variáveis exclusivas;
#     - análise inicial de tipos de dados;
#     - identificação preliminar de nulos;
#     - avaliação inicial de duplicidades;
#     - validação de cobertura temporal;
#     - recomendação sobre integração ou análise separada dos arquivos.
#
# >- Esse diagnóstico será essencial para decidir como avançar para o **Notebook 02 — Data Quality and Preparation**.
#
# </font></div>

# %% [markdown]
# <div style="background-color:#f3f2ee">
#
# <font size="3" color='#CC403E'><strong>📌 11.8 Critério de passagem para a próxima fase</strong></font>
#
# <font size="2" color='#66666'>
#
# >- O projeto estará pronto para avançar do Business Understanding para o Data Understanding quando os seguintes itens estiverem concluídos:
#
# | Item | Status esperado |
# |---|---|
# | Problema de negócio documentado | Concluído |
# | Objetivos definidos | Concluído |
# | Stakeholders mapeados | Concluído |
# | Perguntas analíticas formuladas | Concluído |
# | Hipóteses estruturadas | Concluído |
# | Critérios de sucesso definidos | Concluído |
# | Escopo e premissas documentados | Concluído |
# | Roadmap CRISP-DM+ definido | Concluído |
# | Arquivos CSV disponíveis em `data/00_raw` | Necessário para próxima etapa |
#
# </font></div>

# %% [markdown]
# <div style="background-color:#f3f2ee">
#
# <font size="3" color='#CC403E'><strong>📌 11.9 Encerramento executivo</strong></font>
#
# <font size="2" color='#66666'>
#
# >- O **Notebook 00 — Business Understanding** estabelece a fundação estratégica do projeto **Spotify Global Music Intelligence**.
#
# >- A partir dele, a análise deixa de ser apenas uma exploração técnica de arquivos CSV e passa a ser uma investigação orientada por
#     - problema de negócio, perguntas relevantes, hipóteses testáveis, critérios de sucesso e visão de continuidade.
#
# >- O próximo passo será entrar na fase de **Data Understanding**, avaliando a estrutura real dos dados disponíveis e verificando se eles sustentam as perguntas e hipóteses formuladas.
#
# >- Com isso, o projeto avança de uma formulação estratégica para uma investigação prática baseada em dados.
#
# ---
# </font></div>

# %%
# %reload_ext watermark 
# %watermark -a "Roberto-SSoares-LfLngLrnng" -d -t -u --iversions -v -m -h
# Out:
# Author: Roberto-SSoares-LfLngLrnng
#
# Last updated: 2026-05-04 20:49:18
#
# Python implementation: CPython
# Python version       : 3.12.12
# IPython version      : 9.13.0
#
# Compiler    : MSC v.1944 64 bit (AMD64)
# OS          : Windows
# Release     : 11
# Machine     : AMD64
# Processor   : Intel64 Family 6 Model 158 Stepping 9, GenuineIntel
# CPU cores   : 4
# Architecture: 64bit
#
# Hostname: PC-ROBERTO

# %% [markdown]
# <div style="background-color:#f3f2ee">
#
# <font size="6" color='#CC403E'><strong>FIM</strong></font>
#
# <font size="2" color='#66666'></font></div>
